# %% [markdown]
# # P3 - Open Food Facts - Nettoyage et Exploration

# %% [markdown]
# ### Import

# %%
import sys
import logging
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import missingno as msno
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %matplotlib inline

# %% [markdown]
# ### Error Management

# %%
logging.basicConfig(level=logging.INFO)

# %%
# Les separateurs ne sont pas des comma habituelles, ici il sagit de tabulation. low_memory=False est precise
data = pd.read_csv('../Source/fr.openfoodfacts.org.products.csv', sep='\t', low_memory=False, encoding='UTF-8')

# %% [markdown]
# ### Description du jeu de donnee

# %%
data_shape = data.shape
print(f"Le jeu de donnee contient {data_shape[0]} lignes et {data_shape[1]} colonnes.")
# Out:
# Le jeu de donnee contient 320772 lignes et 162 colonnes.

# %%
data.describe(include='all')
# Out:
#                  code                                                url  \
# count          320749                                             320749
# unique         320749                                             320749
# top     0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
# freq                1                                                  1
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN
#
#                 creator   created_t      created_datetime last_modified_t  \
# count            320770      320769                320763          320772
# unique             3535      189567                189568          180495
# top     usda-ndb-import  1489077120  2017-03-09T10:37:09Z      1439141742
# freq             169868          20                    20              33
# mean                NaN         NaN                   NaN             NaN
# std                 NaN         NaN                   NaN             NaN
# min                 NaN         NaN                   NaN             NaN
# 25%                 NaN         NaN                   NaN             NaN
# 50%                 NaN         NaN                   NaN             NaN
# 75%                 NaN         NaN                   NaN             NaN
# max                 NaN         NaN                   NaN             NaN
#
#        last_modified_datetime product_name  \
# count                  320772       303010
# unique                 180495       221347
# top      2015-08-09T17:35:42Z    Ice Cream
# freq                       33          410
# mean                      NaN          NaN
# std                       NaN          NaN
# min                       NaN          NaN
# 25%                       NaN          NaN
# 50%                       NaN          NaN
# 75%                       NaN          NaN
# max                       NaN          NaN
#
#                                              generic_name quantity  ...  \
# count                                               52795   104819  ...
# unique                                              38584    13826  ...
# top     Pâtes alimentaires au blé dur de qualité supér...    500 g  ...
# freq                                                  201     4669  ...
# mean                                                  NaN      NaN  ...
# std                                                   NaN      NaN  ...
# min                                                   NaN      NaN  ...
# 25%                                                   NaN      NaN  ...
# 50%                                                   NaN      NaN  ...
# 75%                                                   NaN      NaN  ...
# max                                                   NaN      NaN  ...
#
#           ph_100g fruits-vegetables-nuts_100g  \
# count   49.000000                 3036.000000
# unique        NaN                         NaN
# top           NaN                         NaN
# freq          NaN                         NaN
# mean     6.425698                   31.458587
# std      2.047841                   31.967918
# min      0.000000                    0.000000
# 25%      6.300000                    0.000000
# 50%      7.200000                   23.000000
# 75%      7.400000                   51.000000
# max      8.400000                  100.000000
#
#        collagen-meat-protein-ratio_100g  cocoa_100g chlorophyl_100g  \
# count                        165.000000  948.000000             0.0
# unique                              NaN         NaN             NaN
# top                                 NaN         NaN             NaN
# freq                                NaN         NaN             NaN
# mean                          15.412121   49.547785             NaN
# std                            3.753028   18.757932             NaN
# min                            8.000000    6.000000             NaN
# 25%                           12.000000   32.000000             NaN
# 50%                           15.000000   50.000000             NaN
# 75%                           15.000000   64.250000             NaN
# max                           25.000000  100.000000             NaN
#
#        carbon-footprint_100g nutrition-score-fr_100g nutrition-score-uk_100g  \
# count             268.000000           221210.000000           221210.000000
# unique                   NaN                     NaN                     NaN
# top                      NaN                     NaN                     NaN
# freq                     NaN                     NaN                     NaN
# mean              341.700764                9.165535                9.058049
# std               425.211439                9.055903                9.183589
# min                 0.000000              -15.000000              -15.000000
# 25%                98.750000                1.000000                1.000000
# 50%               195.750000               10.000000                9.000000
# 75%               383.200000               16.000000               16.000000
# max              2842.000000               40.000000               40.000000
#
#        glycemic-index_100g water-hardness_100g
# count                  0.0                 0.0
# unique                 NaN                 NaN
# top                    NaN                 NaN
# freq                   NaN                 NaN
# mean                   NaN                 NaN
# std                    NaN                 NaN
# min                    NaN                 NaN
# 25%                    NaN                 NaN
# 50%                    NaN                 NaN
# 75%                    NaN                 NaN
# max                    NaN                 NaN
#
# [11 rows x 162 columns]

# %% [markdown]
# ### Description variable categorielle

# %%
data_lignes = data_shape[0]
desc_var = data.describe(exclude=[np.number])

desc_type = pd.DataFrame(desc_var.dtypes, columns=['type']).T
nb_nan = data_lignes - desc_var.loc['count'].T
pourcentage_nan = nb_nan * 100 / data_lignes
desc_nan = pd.DataFrame([nb_nan, pourcentage_nan], index=['nb_nan', '%_nan'])
desc_var = pd.concat([desc_type, desc_nan, desc_var])

# %%
desc_var
# Out:
#                  code                                                url  \
# type           object                                             object
# nb_nan           23.0                                               23.0
# %_nan         0.00717                                            0.00717
# count          320749                                             320749
# unique         320749                                             320749
# top     0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
# freq                1                                                  1
#
#                 creator   created_t      created_datetime last_modified_t  \
# type             object      object                object          object
# nb_nan              2.0         3.0                   9.0             0.0
# %_nan          0.000623    0.000935              0.002806             0.0
# count            320770      320769                320763          320772
# unique             3535      189567                189568          180495
# top     usda-ndb-import  1489077120  2017-03-09T10:37:09Z      1439141742
# freq             169868          20                    20              33
#
#        last_modified_datetime product_name  \
# type                   object       object
# nb_nan                    0.0      17762.0
# %_nan                     0.0     5.537266
# count                  320772       303010
# unique                 180495       221347
# top      2015-08-09T17:35:42Z    Ice Cream
# freq                       33          410
#
#                                              generic_name   quantity  ...  \
# type                                               object     object  ...
# nb_nan                                           267977.0   215953.0  ...
# %_nan                                           83.541269  67.322896  ...
# count                                               52795     104819  ...
# unique                                              38584      13826  ...
# top     Pâtes alimentaires au blé dur de qualité supér...      500 g  ...
# freq                                                  201       4669  ...
#
#        nutrition_grade_fr pnns_groups_1 pnns_groups_2  \
# type               object        object        object
# nb_nan            99562.0      229259.0      226281.0
# %_nan           31.038245     71.471014     70.542628
# count              221210         91513         94491
# unique                  5            14            42
# top                     d       unknown       unknown
# freq                62763         22624         22624
#
#                                                    states  \
# type                                               object
# nb_nan                                               46.0
# %_nan                                             0.01434
# count                                              320726
# unique                                               1021
# top     en:to-be-completed, en:nutrition-facts-complet...
# freq                                               168905
#
#                                               states_tags  \
# type                                               object
# nb_nan                                               46.0
# %_nan                                             0.01434
# count                                              320726
# unique                                               1021
# top     en:to-be-completed,en:nutrition-facts-complete...
# freq                                               168905
#
#                                                 states_fr main_category  \
# type                                               object        object
# nb_nan                                               46.0      236406.0
# %_nan                                             0.01434     73.699076
# count                                              320726         84366
# unique                                               1021          3543
# top     A compléter,Informations nutritionnelles compl...  en:beverages
# freq                                               168905          6054
#
#        main_category_fr                                          image_url  \
# type             object                                             object
# nb_nan         236406.0                                           244936.0
# %_nan         73.699076                                          76.358286
# count             84366                                              75836
# unique             3543                                              75836
# top            Boissons  http://fr.openfoodfacts.org/images/products/00...
# freq               6054                                                  1
#
#                                           image_small_url
# type                                               object
# nb_nan                                           244936.0
# %_nan                                           76.358286
# count                                               75836
# unique                                              75836
# top     http://fr.openfoodfacts.org/images/products/00...
# freq                                                    1
#
# [7 rows x 56 columns]

# %% [markdown]
# #### 23 unites de difference entre le nombre de ligne (320772) et le nombre de code (320449)

# %% [markdown]
# ### Description variable quantitatve

# %%
data_lignes = data_shape[0]
desc_var = data.describe()

desc_type = pd.DataFrame(desc_var.dtypes, columns=['type']).T
nb_nan = data_lignes - desc_var.loc['count'].T
pourcentage_nan = nb_nan * 100 / data_lignes
desc_nan = pd.DataFrame([nb_nan, pourcentage_nan], index=['nb_nan', '%_nan'])
desc_var = pd.concat([desc_type, desc_nan, desc_var])

# %%
desc_var
# Out:
#        no_nutriments additives_n ingredients_from_palm_oil_n  \
# type         float64     float64                     float64
# nb_nan      320772.0     71833.0                     71833.0
# %_nan          100.0   22.393787                   22.393787
# count            0.0    248939.0                    248939.0
# mean             NaN    1.936024                    0.019659
# std              NaN    2.502019                    0.140524
# min              NaN         0.0                         0.0
# 25%              NaN         0.0                         0.0
# 50%              NaN         1.0                         0.0
# 75%              NaN         3.0                         0.0
# max              NaN        31.0                         2.0
#
#        ingredients_from_palm_oil ingredients_that_may_be_from_palm_oil_n  \
# type                     float64                                 float64
# nb_nan                  320772.0                                 71833.0
# %_nan                      100.0                               22.393787
# count                        0.0                                248939.0
# mean                         NaN                                0.055246
# std                          NaN                                0.269207
# min                          NaN                                     0.0
# 25%                          NaN                                     0.0
# 50%                          NaN                                     0.0
# 75%                          NaN                                     0.0
# max                          NaN                                     6.0
#
#        ingredients_that_may_be_from_palm_oil nutrition_grade_uk  energy_100g  \
# type                                 float64            float64      float64
# nb_nan                              320772.0           320772.0      59659.0
# %_nan                                  100.0              100.0    18.598568
# count                                    0.0                0.0     261113.0
# mean                                     NaN                NaN  1141.914605
# std                                      NaN                NaN  6447.154093
# min                                      NaN                NaN          0.0
# 25%                                      NaN                NaN        377.0
# 50%                                      NaN                NaN       1100.0
# 75%                                      NaN                NaN       1674.0
# max                                      NaN                NaN    3251373.0
#
#        energy-from-fat_100g   fat_100g  ...    ph_100g  \
# type                float64    float64  ...    float64
# nb_nan             319915.0    76881.0  ...   320723.0
# %_nan             99.732832  23.967491  ...  99.984724
# count                 857.0   243891.0  ...       49.0
# mean             585.501214  12.730379  ...   6.425698
# std              712.809943  17.578747  ...   2.047841
# min                     0.0        0.0  ...        0.0
# 25%                    49.4        0.0  ...        6.3
# 50%                   300.0        5.0  ...        7.2
# 75%                   898.0       20.0  ...        7.4
# max                  3830.0     714.29  ...        8.4
#
#        fruits-vegetables-nuts_100g collagen-meat-protein-ratio_100g  \
# type                       float64                          float64
# nb_nan                    317736.0                         320607.0
# %_nan                    99.053533                        99.948562
# count                       3036.0                            165.0
# mean                     31.458587                        15.412121
# std                      31.967918                         3.753028
# min                            0.0                              8.0
# 25%                            0.0                             12.0
# 50%                           23.0                             15.0
# 75%                           51.0                             15.0
# max                          100.0                             25.0
#
#        cocoa_100g chlorophyl_100g carbon-footprint_100g  \
# type      float64         float64               float64
# nb_nan   319824.0        320772.0              320504.0
# %_nan   99.704463           100.0             99.916452
# count       948.0             0.0                 268.0
# mean    49.547785             NaN            341.700764
# std     18.757932             NaN            425.211439
# min           6.0             NaN                   0.0
# 25%          32.0             NaN                 98.75
# 50%          50.0             NaN                195.75
# 75%         64.25             NaN                 383.2
# max         100.0             NaN                2842.0
#
#        nutrition-score-fr_100g nutrition-score-uk_100g glycemic-index_100g  \
# type                   float64                 float64             float64
# nb_nan                 99562.0                 99562.0            320772.0
# %_nan                31.038245               31.038245               100.0
# count                 221210.0                221210.0                 0.0
# mean                  9.165535                9.058049                 NaN
# std                   9.055903                9.183589                 NaN
# min                      -15.0                   -15.0                 NaN
# 25%                        1.0                     1.0                 NaN
# 50%                       10.0                     9.0                 NaN
# 75%                       16.0                    16.0                 NaN
# max                       40.0                    40.0                 NaN
#
#        water-hardness_100g
# type               float64
# nb_nan            320772.0
# %_nan                100.0
# count                  0.0
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN
#
# [11 rows x 106 columns]

# %% [markdown]
# #### On remarque que dans plusieurs colonnes _100g, des valeurs supperieurs a 100 sont presentes

# %%
data.head(5)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
# 1  0000000004530  http://world-fr.openfoodfacts.org/produit/0000...
# 2  0000000004559  http://world-fr.openfoodfacts.org/produit/0000...
# 3  0000000016087  http://world-fr.openfoodfacts.org/produit/0000...
# 4  0000000016094  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2      1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3      1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4      1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#   generic_name quantity  ... ph_100g fruits-vegetables-nuts_100g  \
# 0          NaN      1kg  ...     NaN                         NaN
# 1          NaN      NaN  ...     NaN                         NaN
# 2          NaN      NaN  ...     NaN                         NaN
# 3          NaN      NaN  ...     NaN                         NaN
# 4          NaN      NaN  ...     NaN                         NaN
#
#   collagen-meat-protein-ratio_100g cocoa_100g chlorophyl_100g  \
# 0                              NaN        NaN             NaN
# 1                              NaN        NaN             NaN
# 2                              NaN        NaN             NaN
# 3                              NaN        NaN             NaN
# 4                              NaN        NaN             NaN
#
#   carbon-footprint_100g nutrition-score-fr_100g nutrition-score-uk_100g  \
# 0                   NaN                     NaN                     NaN
# 1                   NaN                    14.0                    14.0
# 2                   NaN                     0.0                     0.0
# 3                   NaN                    12.0                    12.0
# 4                   NaN                     NaN                     NaN
#
#   glycemic-index_100g water-hardness_100g
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN
#
# [5 rows x 162 columns]

# %%
data.columns.tolist()
# Out:
# ['code',
#  'url',
#  'creator',
#  'created_t',
#  'created_datetime',
#  'last_modified_t',
#  'last_modified_datetime',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_fr',
#  'origins',
#  'origins_tags',
#  'manufacturing_places',
#  'manufacturing_places_tags',
#  'labels',
#  'labels_tags',
#  'labels_fr',
#  'emb_codes',
#  'emb_codes_tags',
#  'first_packaging_code_geo',
#  'cities',
#  'cities_tags',
#  'purchase_places',
#  'stores',
#  'countries',
#  'countries_tags',
#  'countries_fr',
#  'ingredients_text',
#  'allergens',
#  'allergens_fr',
#  'traces',
#  'traces_tags',
#  'traces_fr',
#  'serving_size',
#  'no_nutriments',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'additives_fr',
#  'ingredients_from_palm_oil_n',
#  'ingredients_from_palm_oil',
#  'ingredients_from_palm_oil_tags',
#  'ingredients_that_may_be_from_palm_oil_n',
#  'ingredients_that_may_be_from_palm_oil',
#  'ingredients_that_may_be_from_palm_oil_tags',
#  'nutrition_grade_uk',
#  'nutrition_grade_fr',
#  'pnns_groups_1',
#  'pnns_groups_2',
#  'states',
#  'states_tags',
#  'states_fr',
#  'main_category',
#  'main_category_fr',
#  'image_url',
#  'image_small_url',
#  'energy_100g',
#  'energy-from-fat_100g',
#  'fat_100g',
#  'saturated-fat_100g',
#  'butyric-acid_100g',
#  'caproic-acid_100g',
#  'caprylic-acid_100g',
#  'capric-acid_100g',
#  'lauric-acid_100g',
#  'myristic-acid_100g',
#  'palmitic-acid_100g',
#  'stearic-acid_100g',
#  'arachidic-acid_100g',
#  'behenic-acid_100g',
#  'lignoceric-acid_100g',
#  'cerotic-acid_100g',
#  'montanic-acid_100g',
#  'melissic-acid_100g',
#  'monounsaturated-fat_100g',
#  'polyunsaturated-fat_100g',
#  'omega-3-fat_100g',
#  'alpha-linolenic-acid_100g',
#  'eicosapentaenoic-acid_100g',
#  'docosahexaenoic-acid_100g',
#  'omega-6-fat_100g',
#  'linoleic-acid_100g',
#  'arachidonic-acid_100g',
#  'gamma-linolenic-acid_100g',
#  'dihomo-gamma-linolenic-acid_100g',
#  'omega-9-fat_100g',
#  'oleic-acid_100g',
#  'elaidic-acid_100g',
#  'gondoic-acid_100g',
#  'mead-acid_100g',
#  'erucic-acid_100g',
#  'nervonic-acid_100g',
#  'trans-fat_100g',
#  'cholesterol_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  'sucrose_100g',
#  'glucose_100g',
#  'fructose_100g',
#  'lactose_100g',
#  'maltose_100g',
#  'maltodextrins_100g',
#  'starch_100g',
#  'polyols_100g',
#  'fiber_100g',
#  'proteins_100g',
#  'casein_100g',
#  'serum-proteins_100g',
#  'nucleotides_100g',
#  'salt_100g',
#  'sodium_100g',
#  'alcohol_100g',
#  'vitamin-a_100g',
#  'beta-carotene_100g',
#  'vitamin-d_100g',
#  'vitamin-e_100g',
#  'vitamin-k_100g',
#  'vitamin-c_100g',
#  'vitamin-b1_100g',
#  'vitamin-b2_100g',
#  'vitamin-pp_100g',
#  'vitamin-b6_100g',
#  'vitamin-b9_100g',
#  'folates_100g',
#  'vitamin-b12_100g',
#  'biotin_100g',
#  'pantothenic-acid_100g',
#  'silica_100g',
#  'bicarbonate_100g',
#  'potassium_100g',
#  'chloride_100g',
#  'calcium_100g',
#  'phosphorus_100g',
#  'iron_100g',
#  'magnesium_100g',
#  'zinc_100g',
#  'copper_100g',
#  'manganese_100g',
#  'fluoride_100g',
#  'selenium_100g',
#  'chromium_100g',
#  'molybdenum_100g',
#  'iodine_100g',
#  'caffeine_100g',
#  'taurine_100g',
#  'ph_100g',
#  'fruits-vegetables-nuts_100g',
#  'collagen-meat-protein-ratio_100g',
#  'cocoa_100g',
#  'chlorophyl_100g',
#  'carbon-footprint_100g',
#  'nutrition-score-fr_100g',
#  'nutrition-score-uk_100g',
#  'glycemic-index_100g',
#  'water-hardness_100g']

# %%
data.dtypes
# Out:
# code                        object
# url                         object
# creator                     object
# created_t                   object
# created_datetime            object
#                             ...
# carbon-footprint_100g      float64
# nutrition-score-fr_100g    float64
# nutrition-score-uk_100g    float64
# glycemic-index_100g        float64
# water-hardness_100g        float64
# Length: 162, dtype: object

# %%
data['countries_fr'].value_counts()
# Out:
# countries_fr
# États-Unis                                      172998
# France                                           94392
# Suisse                                           14953
# Allemagne                                         7870
# Espagne                                           5009
#                                                  ...
# Danemark,Suisse,en:Deutschland,en:Frankreich         1
# France,Luxembourg,Suisse                             1
# Autriche,République tchèque,Allemagne                1
# Allemagne,Hongrie                                    1
# Chine,Hong Kong                                      1
# Name: count, Length: 722, dtype: int64

# %% [markdown]
# ## Selection des produits vendus en France

# %%
# Filtre sur la France
mask = data['countries_fr'].str.contains('France', na=False)
data_fr = data[mask].drop(['countries', 'countries_tags', 'countries_fr'], axis=1)

# %%
data_fr.shape
# Out:
# (98440, 159)

# %%
values = data_fr.dtypes.value_counts()
nb_tot = values.sum()
percentages = round((100 * values / nb_tot), 2)
table = pd.concat([values, percentages], axis=1)
table.columns = ['Nombre par type de variable', '% des types de variable']

# %%
table.loc[table['Nombre par type de variable'] != 0].sort_values('% des types de variable', ascending=False).style.background_gradient('seismic')
# Out:
# <style type="text/css">
# #T_54729_row0_col0, #T_54729_row0_col1 {
#   background-color: #800000;
#   color: #f1f1f1;
# }
# #T_54729_row1_col0, #T_54729_row1_col1 {
#   background-color: #00004c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_54729">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54729_level0_col0" class="col_heading level0 col0" >Nombre par type de variable</th>
#       <th id="T_54729_level0_col1" class="col_heading level0 col1" >% des types de variable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54729_level0_row0" class="row_heading level0 row0" >float64</th>
#       <td id="T_54729_row0_col0" class="data row0 col0" >106</td>
#       <td id="T_54729_row0_col1" class="data row0 col1" >66.670000</td>
#     </tr>
#     <tr>
#       <th id="T_54729_level0_row1" class="row_heading level0 row1" >object</th>
#       <td id="T_54729_row1_col0" class="data row1 col0" >53</td>
#       <td id="T_54729_row1_col1" class="data row1 col1" >33.330000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Pie chart
data_fr.dtypes.value_counts().plot.pie()
plt.ylabel('')
plt.show()

# %%
# pourcentage des valeurs manquantes
nan_tot =  data_fr.isna().sum().sum()
data_tot = np.product(data_fr.shape)
percentage = round((nan_tot / data_tot) * 100, 2)
print(f'Valeurs manquantes :{nan_tot} NaN pour {data_tot} données ({percentage} %)')
# Out:
# Valeurs manquantes :12100261 NaN pour 15651960 données (77.31 %)

# %% [markdown]
# #### 77% de valeurs sont manquantes

# %%
values = data_fr.isnull().sum()
percentage = 100 * values / len(data_fr)
table = pd.concat([values, percentage.round(2)], axis=1)
table.columns = ['Nombres de valeurs manquantes', '% de valeurs manquantes']
table.loc[table['Nombres de valeurs manquantes'] != 0].sort_values('% de valeurs manquantes', ascending=False).style.background_gradient('Greens')
# Out:
# <style type="text/css">
# #T_a7372_row0_col0, #T_a7372_row0_col1, #T_a7372_row1_col0, #T_a7372_row1_col1, #T_a7372_row2_col0, #T_a7372_row2_col1, #T_a7372_row3_col0, #T_a7372_row3_col1, #T_a7372_row4_col0, #T_a7372_row4_col1, #T_a7372_row5_col0, #T_a7372_row5_col1, #T_a7372_row6_col0, #T_a7372_row6_col1, #T_a7372_row7_col0, #T_a7372_row7_col1, #T_a7372_row8_col0, #T_a7372_row8_col1, #T_a7372_row9_col0, #T_a7372_row9_col1, #T_a7372_row10_col0, #T_a7372_row10_col1, #T_a7372_row11_col0, #T_a7372_row11_col1, #T_a7372_row12_col0, #T_a7372_row12_col1, #T_a7372_row13_col0, #T_a7372_row13_col1, #T_a7372_row14_col0, #T_a7372_row14_col1, #T_a7372_row15_col0, #T_a7372_row15_col1, #T_a7372_row16_col0, #T_a7372_row16_col1, #T_a7372_row17_col0, #T_a7372_row17_col1, #T_a7372_row18_col0, #T_a7372_row18_col1, #T_a7372_row19_col0, #T_a7372_row19_col1, #T_a7372_row20_col0, #T_a7372_row20_col1, #T_a7372_row21_col0, #T_a7372_row21_col1, #T_a7372_row22_col0, #T_a7372_row22_col1, #T_a7372_row23_col0, #T_a7372_row23_col1, #T_a7372_row24_col0, #T_a7372_row24_col1, #T_a7372_row25_col0, #T_a7372_row25_col1, #T_a7372_row26_col0, #T_a7372_row26_col1, #T_a7372_row27_col0, #T_a7372_row27_col1, #T_a7372_row28_col0, #T_a7372_row28_col1, #T_a7372_row29_col0, #T_a7372_row29_col1, #T_a7372_row30_col0, #T_a7372_row30_col1, #T_a7372_row31_col0, #T_a7372_row31_col1, #T_a7372_row32_col0, #T_a7372_row32_col1, #T_a7372_row33_col0, #T_a7372_row33_col1, #T_a7372_row34_col0, #T_a7372_row34_col1, #T_a7372_row35_col0, #T_a7372_row35_col1, #T_a7372_row36_col0, #T_a7372_row36_col1, #T_a7372_row37_col0, #T_a7372_row37_col1, #T_a7372_row38_col0, #T_a7372_row38_col1, #T_a7372_row39_col0, #T_a7372_row39_col1, #T_a7372_row40_col0, #T_a7372_row40_col1, #T_a7372_row41_col0, #T_a7372_row41_col1, #T_a7372_row42_col0, #T_a7372_row42_col1, #T_a7372_row43_col0, #T_a7372_row43_col1, #T_a7372_row44_col0, #T_a7372_row44_col1, #T_a7372_row45_col0, #T_a7372_row45_col1, #T_a7372_row46_col0, #T_a7372_row46_col1, #T_a7372_row47_col0, #T_a7372_row47_col1, #T_a7372_row48_col0, #T_a7372_row48_col1, #T_a7372_row49_col0, #T_a7372_row49_col1, #T_a7372_row50_col0, #T_a7372_row50_col1, #T_a7372_row51_col0, #T_a7372_row51_col1, #T_a7372_row52_col0, #T_a7372_row52_col1, #T_a7372_row53_col0, #T_a7372_row53_col1, #T_a7372_row54_col0, #T_a7372_row54_col1, #T_a7372_row55_col0, #T_a7372_row55_col1, #T_a7372_row56_col0, #T_a7372_row56_col1, #T_a7372_row57_col0, #T_a7372_row57_col1, #T_a7372_row58_col0, #T_a7372_row58_col1, #T_a7372_row59_col0, #T_a7372_row59_col1, #T_a7372_row60_col0, #T_a7372_row60_col1, #T_a7372_row61_col0, #T_a7372_row61_col1, #T_a7372_row62_col0, #T_a7372_row62_col1, #T_a7372_row63_col0, #T_a7372_row63_col1, #T_a7372_row64_col0, #T_a7372_row64_col1, #T_a7372_row65_col0, #T_a7372_row65_col1, #T_a7372_row66_col0, #T_a7372_row66_col1, #T_a7372_row67_col0, #T_a7372_row67_col1, #T_a7372_row68_col0, #T_a7372_row68_col1, #T_a7372_row69_col0, #T_a7372_row69_col1, #T_a7372_row70_col0, #T_a7372_row70_col1, #T_a7372_row71_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a7372_row71_col0, #T_a7372_row72_col0, #T_a7372_row72_col1, #T_a7372_row73_col0, #T_a7372_row73_col1, #T_a7372_row74_col0, #T_a7372_row74_col1, #T_a7372_row75_col0, #T_a7372_row75_col1, #T_a7372_row76_col0, #T_a7372_row76_col1, #T_a7372_row77_col0, #T_a7372_row77_col1, #T_a7372_row78_col0, #T_a7372_row78_col1, #T_a7372_row79_col0, #T_a7372_row79_col1, #T_a7372_row80_col0, #T_a7372_row80_col1, #T_a7372_row81_col0, #T_a7372_row81_col1, #T_a7372_row82_col0, #T_a7372_row82_col1, #T_a7372_row83_col0, #T_a7372_row83_col1 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_a7372_row84_col0, #T_a7372_row84_col1, #T_a7372_row85_col0, #T_a7372_row85_col1, #T_a7372_row86_col0, #T_a7372_row86_col1 {
#   background-color: #00471c;
#   color: #f1f1f1;
# }
# #T_a7372_row87_col0, #T_a7372_row87_col1, #T_a7372_row88_col0, #T_a7372_row88_col1, #T_a7372_row89_col0, #T_a7372_row89_col1, #T_a7372_row90_col0, #T_a7372_row90_col1 {
#   background-color: #00481d;
#   color: #f1f1f1;
# }
# #T_a7372_row91_col0, #T_a7372_row91_col1 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_a7372_row92_col0, #T_a7372_row92_col1 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_a7372_row93_col0, #T_a7372_row93_col1 {
#   background-color: #004d1f;
#   color: #f1f1f1;
# }
# #T_a7372_row94_col0, #T_a7372_row94_col1 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_a7372_row95_col0, #T_a7372_row95_col1 {
#   background-color: #005924;
#   color: #f1f1f1;
# }
# #T_a7372_row96_col0, #T_a7372_row96_col1, #T_a7372_row97_col0, #T_a7372_row97_col1 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_a7372_row98_col0, #T_a7372_row98_col1 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_a7372_row99_col0, #T_a7372_row99_col1, #T_a7372_row100_col0, #T_a7372_row100_col1, #T_a7372_row101_col0, #T_a7372_row101_col1 {
#   background-color: #137d39;
#   color: #f1f1f1;
# }
# #T_a7372_row102_col0, #T_a7372_row102_col1 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# #T_a7372_row103_col0, #T_a7372_row103_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_a7372_row104_col0, #T_a7372_row104_col1, #T_a7372_row105_col0, #T_a7372_row105_col1 {
#   background-color: #1f8742;
#   color: #f1f1f1;
# }
# #T_a7372_row106_col0, #T_a7372_row106_col1, #T_a7372_row107_col0, #T_a7372_row107_col1 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_a7372_row108_col0, #T_a7372_row108_col1 {
#   background-color: #278f48;
#   color: #f1f1f1;
# }
# #T_a7372_row109_col0, #T_a7372_row109_col1, #T_a7372_row110_col0, #T_a7372_row110_col1 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_a7372_row111_col0, #T_a7372_row111_col1, #T_a7372_row112_col0, #T_a7372_row112_col1, #T_a7372_row113_col0, #T_a7372_row113_col1 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_a7372_row114_col0, #T_a7372_row114_col1 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_a7372_row115_col0, #T_a7372_row115_col1 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_a7372_row116_col0, #T_a7372_row116_col1 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_a7372_row117_col0, #T_a7372_row117_col1 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_a7372_row118_col0, #T_a7372_row118_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_a7372_row119_col0, #T_a7372_row119_col1 {
#   background-color: #6dc072;
#   color: #000000;
# }
# #T_a7372_row120_col0, #T_a7372_row120_col1, #T_a7372_row121_col0, #T_a7372_row121_col1 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_a7372_row122_col0, #T_a7372_row122_col1, #T_a7372_row123_col0, #T_a7372_row123_col1, #T_a7372_row124_col0, #T_a7372_row124_col1, #T_a7372_row125_col0, #T_a7372_row125_col1, #T_a7372_row126_col0, #T_a7372_row126_col1 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_a7372_row127_col0, #T_a7372_row127_col1, #T_a7372_row128_col0, #T_a7372_row128_col1 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_a7372_row129_col0, #T_a7372_row129_col1, #T_a7372_row130_col0, #T_a7372_row130_col1, #T_a7372_row131_col0, #T_a7372_row131_col1 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_a7372_row132_col0, #T_a7372_row132_col1, #T_a7372_row133_col0, #T_a7372_row133_col1, #T_a7372_row134_col0, #T_a7372_row134_col1, #T_a7372_row135_col0, #T_a7372_row135_col1, #T_a7372_row136_col0, #T_a7372_row136_col1 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_a7372_row137_col0, #T_a7372_row137_col1, #T_a7372_row138_col0, #T_a7372_row138_col1, #T_a7372_row139_col0, #T_a7372_row139_col1, #T_a7372_row140_col0, #T_a7372_row140_col1 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_a7372_row141_col0, #T_a7372_row141_col1, #T_a7372_row142_col0, #T_a7372_row142_col1 {
#   background-color: #aadda4;
#   color: #000000;
# }
# #T_a7372_row143_col0, #T_a7372_row143_col1 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_a7372_row144_col0, #T_a7372_row144_col1 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_a7372_row145_col0, #T_a7372_row145_col1 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_a7372_row146_col0,

# %% [markdown]
# #### De nombreuses valeurs depassent les 70% de valeurs manquantes

# %%
print("-------------------------------------------------------------")
print("Heatmap de visualisation des valeurs manquantes")
plt.figure(figsize=(20, 10))
sns.heatmap(data_fr.isna(), cbar=False)
plt.show()
# Out:
# -------------------------------------------------------------
# Heatmap de visualisation des valeurs manquantes

# %%
# Répartition du pourcentage de valeurs manquantes pour toutes les variables provisoirement conservées
plt.figure(figsize=(40, 15))
data_retained_nan = round((data_fr.isna().sum()/data_fr.shape[0]) * 100, 2)
data_retained_nan.sort_values(inplace=True)
data_retained_nan.plot(kind='bar', color='SteelBlue')
plt.title('Répartition du pourcentage de valeurs manquantes par variables provisoirement conservées', fontsize=35)
plt.ylabel('% Nan', fontsize=30)
plt.axhline(y=70, color='r')
plt.text(2, 82, '>70% NaN - A supprimer', color='r', fontsize=30)
plt.show()

# %% [markdown]
# ### Nettoyage + correction du jeu de donnees

# %%
data_fr.columns.tolist()
# Out:
# ['code',
#  'url',
#  'creator',
#  'created_t',
#  'created_datetime',
#  'last_modified_t',
#  'last_modified_datetime',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_fr',
#  'origins',
#  'origins_tags',
#  'manufacturing_places',
#  'manufacturing_places_tags',
#  'labels',
#  'labels_tags',
#  'labels_fr',
#  'emb_codes',
#  'emb_codes_tags',
#  'first_packaging_code_geo',
#  'cities',
#  'cities_tags',
#  'purchase_places',
#  'stores',
#  'ingredients_text',
#  'allergens',
#  'allergens_fr',
#  'traces',
#  'traces_tags',
#  'traces_fr',
#  'serving_size',
#  'no_nutriments',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'additives_fr',
#  'ingredients_from_palm_oil_n',
#  'ingredients_from_palm_oil',
#  'ingredients_from_palm_oil_tags',
#  'ingredients_that_may_be_from_palm_oil_n',
#  'ingredients_that_may_be_from_palm_oil',
#  'ingredients_that_may_be_from_palm_oil_tags',
#  'nutrition_grade_uk',
#  'nutrition_grade_fr',
#  'pnns_groups_1',
#  'pnns_groups_2',
#  'states',
#  'states_tags',
#  'states_fr',
#  'main_category',
#  'main_category_fr',
#  'image_url',
#  'image_small_url',
#  'energy_100g',
#  'energy-from-fat_100g',
#  'fat_100g',
#  'saturated-fat_100g',
#  'butyric-acid_100g',
#  'caproic-acid_100g',
#  'caprylic-acid_100g',
#  'capric-acid_100g',
#  'lauric-acid_100g',
#  'myristic-acid_100g',
#  'palmitic-acid_100g',
#  'stearic-acid_100g',
#  'arachidic-acid_100g',
#  'behenic-acid_100g',
#  'lignoceric-acid_100g',
#  'cerotic-acid_100g',
#  'montanic-acid_100g',
#  'melissic-acid_100g',
#  'monounsaturated-fat_100g',
#  'polyunsaturated-fat_100g',
#  'omega-3-fat_100g',
#  'alpha-linolenic-acid_100g',
#  'eicosapentaenoic-acid_100g',
#  'docosahexaenoic-acid_100g',
#  'omega-6-fat_100g',
#  'linoleic-acid_100g',
#  'arachidonic-acid_100g',
#  'gamma-linolenic-acid_100g',
#  'dihomo-gamma-linolenic-acid_100g',
#  'omega-9-fat_100g',
#  'oleic-acid_100g',
#  'elaidic-acid_100g',
#  'gondoic-acid_100g',
#  'mead-acid_100g',
#  'erucic-acid_100g',
#  'nervonic-acid_100g',
#  'trans-fat_100g',
#  'cholesterol_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  'sucrose_100g',
#  'glucose_100g',
#  'fructose_100g',
#  'lactose_100g',
#  'maltose_100g',
#  'maltodextrins_100g',
#  'starch_100g',
#  'polyols_100g',
#  'fiber_100g',
#  'proteins_100g',
#  'casein_100g',
#  'serum-proteins_100g',
#  'nucleotides_100g',
#  'salt_100g',
#  'sodium_100g',
#  'alcohol_100g',
#  'vitamin-a_100g',
#  'beta-carotene_100g',
#  'vitamin-d_100g',
#  'vitamin-e_100g',
#  'vitamin-k_100g',
#  'vitamin-c_100g',
#  'vitamin-b1_100g',
#  'vitamin-b2_100g',
#  'vitamin-pp_100g',
#  'vitamin-b6_100g',
#  'vitamin-b9_100g',
#  'folates_100g',
#  'vitamin-b12_100g',
#  'biotin_100g',
#  'pantothenic-acid_100g',
#  'silica_100g',
#  'bicarbonate_100g',
#  'potassium_100g',
#  'chloride_100g',
#  'calcium_100g',
#  'phosphorus_100g',
#  'iron_100g',
#  'magnesium_100g',
#  'zinc_100g',
#  'copper_100g',
#  'manganese_100g',
#  'fluoride_100g',
#  'selenium_100g',
#  'chromium_100g',
#  'molybdenum_100g',
#  'iodine_100g',
#  'caffeine_100g',
#  'taurine_100g',
#  'ph_100g',
#  'fruits-vegetables-nuts_100g',
#  'collagen-meat-protein-ratio_100g',
#  'cocoa_100g',
#  'chlorophyl_100g',
#  'carbon-footprint_100g',
#  'nutrition-score-fr_100g',
#  'nutrition-score-uk_100g',
#  'glycemic-index_100g',
#  'water-hardness_100g']

# %%
# Correction de la synthaxe
car_avant = '-'
car_apres = '_'

cols_a_renommer = data_fr.columns[data_fr.columns.str.contains(car_avant)]
print(f"{len(cols_a_renommer)} variables renommées {car_avant} en {car_apres} : \n\n {cols_a_renommer.tolist()}")

data_fr.columns = data_fr.columns.str.replace(car_avant, car_apres)
# Out:
# 56 variables renommées - en _ :
#
#  ['energy-from-fat_100g', 'saturated-fat_100g', 'butyric-acid_100g', 'caproic-acid_100g', 'caprylic-acid_100g', 'capric-acid_100g', 'lauric-acid_100g', 'myristic-acid_100g', 'palmitic-acid_100g', 'stearic-acid_100g', 'arachidic-acid_100g', 'behenic-acid_100g', 'lignoceric-acid_100g', 'cerotic-acid_100g', 'montanic-acid_100g', 'melissic-acid_100g', 'monounsaturated-fat_100g', 'polyunsaturated-fat_100g', 'omega-3-fat_100g', 'alpha-linolenic-acid_100g', 'eicosapentaenoic-acid_100g', 'docosahexaenoic-acid_100g', 'omega-6-fat_100g', 'linoleic-acid_100g', 'arachidonic-acid_100g', 'gamma-linolenic-acid_100g', 'dihomo-gamma-linolenic-acid_100g', 'omega-9-fat_100g', 'oleic-acid_100g', 'elaidic-acid_100g', 'gondoic-acid_100g', 'mead-acid_100g', 'erucic-acid_100g', 'nervonic-acid_100g', 'trans-fat_100g', 'serum-proteins_100g', 'vitamin-a_100g', 'beta-carotene_100g', 'vitamin-d_100g', 'vitamin-e_100g', 'vitamin-k_100g', 'vitamin-c_100g', 'vitamin-b1_100g', 'vitamin-b2_100g', 'vitamin-pp_100g', 'vitamin-b6_100g', 'vitamin-b9_100g', 'vitamin-b12_100g', 'pantothenic-acid_100g', 'fruits-vegetables-nuts_100g', 'collagen-meat-protein-ratio_100g', 'carbon-footprint_100g', 'nutrition-score-fr_100g', 'nutrition-score-uk_100g', 'glycemic-index_100g', 'water-hardness_100g']

# %%
nb_lignes = data_fr.shape[0]
sum_nan = data_fr.isna().sum()

df_nan = pd.DataFrame({'Variable': sum_nan.index,
                           'nb_nan': sum_nan.values})

df_nan['%_nan'] = [(row * 100) / nb_lignes for row in df_nan['nb_nan']]
df_nan['%_nan_groupe'] = pd.cut(df_nan['%_nan'], bins=[0, 10, 20, 40, 60, 80, 100])
sum_gpe_nan = df_nan['%_nan_groupe'].value_counts().sort_index()

df_group_nan = pd.DataFrame({'Plage de %': sum_gpe_nan.index,
                              'nb_variable': sum_gpe_nan.values})

# %%
df_nan
# Out:
#                     Variable  nb_nan       %_nan   %_nan_groupe
# 0                       code       0    0.000000            NaN
# 1                        url       0    0.000000            NaN
# 2                    creator       0    0.000000            NaN
# 3                  created_t       0    0.000000            NaN
# 4           created_datetime       1    0.001016    (0.0, 10.0]
# ..                       ...     ...         ...            ...
# 154    carbon_footprint_100g   98264   99.821211  (80.0, 100.0]
# 155  nutrition_score_fr_100g   37025   37.611743   (20.0, 40.0]
# 156  nutrition_score_uk_100g   37025   37.611743   (20.0, 40.0]
# 157      glycemic_index_100g   98440  100.000000  (80.0, 100.0]
# 158      water_hardness_100g   98440  100.000000  (80.0, 100.0]
#
# [159 rows x 4 columns]

# %%
df_group_nan
# Out:
#   Plage de %  nb_variable
# 0    (0, 10]            2
# 1   (10, 20]            2
# 2   (20, 40]           17
# 3   (40, 60]           13
# 4   (60, 80]           14
# 5  (80, 100]          102

# %% [markdown]
# #### 102 variables avec plus de 80% de valeurs manquantes.
# #### 14 variables avec plus de 60% de valeurs manquantes.
# #### Conclusion : la suppression des variables très peu renseignées devra être effectuée.

# %%
# Ajout d'un seuil pour retirer les donnees avec trop de valeurs manquantes > 70%
threshold = 0.3 * data_fr.shape[0]
data_fr_retained = data_fr.dropna(axis=1, thresh=threshold)

# %%
data_fr_retained.columns.tolist()
# Out:
# ['code',
#  'url',
#  'creator',
#  'created_t',
#  'created_datetime',
#  'last_modified_t',
#  'last_modified_datetime',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_fr',
#  'labels',
#  'labels_tags',
#  'labels_fr',
#  'purchase_places',
#  'stores',
#  'ingredients_text',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'additives_fr',
#  'ingredients_from_palm_oil_n',
#  'ingredients_that_may_be_from_palm_oil_n',
#  'nutrition_grade_fr',
#  'pnns_groups_1',
#  'pnns_groups_2',
#  'states',
#  'states_tags',
#  'states_fr',
#  'main_category',
#  'main_category_fr',
#  'image_url',
#  'image_small_url',
#  'energy_100g',
#  'fat_100g',
#  'saturated_fat_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  'fiber_100g',
#  'proteins_100g',
#  'salt_100g',
#  'sodium_100g',
#  'nutrition_score_fr_100g',
#  'nutrition_score_uk_100g']

# %%
# Répartition des valeurs renseignées par variables
fig, ax = plt.subplots(figsize=(15, 25))

# Graphique ligne 1, colonne 1 ------------------
# Répartition des valeurs renseignées par variables
present = data_fr_retained.count()
present.sort_values(inplace=True)
ax.barh(y=present.index, width=present.values, color='SteelBlue')
for i, v in enumerate(present):
    ax.text(v + 5, i - .25, str(v), color='SteelBlue',
            fontsize=10, fontweight='bold')
ax.set_title('Nombre de données par variables', fontsize=16)
ax.set_xlabel('Nombre de données', fontsize=12)
ax.set_ylabel('Variables', fontsize=12)
ax.tick_params(labelsize=10)
ax.set_xlim([0, 110000])
ax.set_ylim([-1, 50])
ax.grid(False)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Suppression des varibales sans interet

# %%
data_fr_retained = data_fr_retained.drop(['code', 'creator', 'created_t', 'created_datetime', 'last_modified_t', 'last_modified_datetime',
                'quantity', 'packaging', 'packaging_tags', 'additives_n', 'additives',
                'ingredients_from_palm_oil_n', 'ingredients_that_may_be_from_palm_oil_n', 'states',
                'states_tags', 'states_fr', 'image_url', 'image_small_url'], axis=1)
data_fr_retained.shape
# Out:
# (98440, 32)

# %%
data_fr_retained_shape = data_fr_retained.shape
print(f"Le jeu de donnee contient {data_fr_retained_shape[0]} lignes et {data_fr_retained_shape[1]} colonnes.")
# Out:
# Le jeu de donnee contient 98440 lignes et 32 colonnes.

# %% [markdown]
# ## Conversiond e la valeur energetique en calories pour 100g de produit

# %%
data_fr_retained['energy_100g']
# Out:
# 0            NaN
# 46           NaN
# 48           NaN
# 106       1883.0
# 136          NaN
#            ...
# 320761       NaN
# 320763      21.0
# 320764       NaN
# 320765       NaN
# 320770       NaN
# Name: energy_100g, Length: 98440, dtype: float64

# %%
data_fr_retained['energy_100g'] = data_fr_retained['energy_100g'] / 4.184

# %%
data_fr_retained['energy_100g']
# Out:
# 0                NaN
# 46               NaN
# 48               NaN
# 106       450.047801
# 136              NaN
#              ...
# 320761           NaN
# 320763      5.019120
# 320764           NaN
# 320765           NaN
# 320770           NaN
# Name: energy_100g, Length: 98440, dtype: float64

# %%
# Information generales, comparaison des colonnes generic_name vs product_name

data_product = data_fr_retained.loc[data_fr_retained['generic_name'] != data_fr_retained['product_name']]
data_product = data_product[['generic_name', 'product_name']][data_product['generic_name'].notnull()]
data_product
# Out:
#                                              generic_name  \
# 184           Biscuits sablés déclassés fourrage au cacao
# 187                        Bonbons acidulés Raisin Fraise
# 226     Boisson gazeuse rafraîchissante aux extraits n...
# 240     Boisson gazeuse aux extraits naturels de citro...
# 279                         Pâtisseries aux raisins secs.
# ...                                                   ...
# 320681  Pastilles avec chlorophylle au gout menthe ave...
# 320736                                  semoule de manioc
# 320758                                               Miel
# 320761                                Vins blanc du Bugey
# 320763                                  thé bio équitable
#
#                              product_name
# 184     Biscuits sablés fourrage au cacao
# 187                                   NaN
# 226                 Pepsi, Nouveau goût !
# 240                                   7Up
# 279                         Cakes Raisins
# ...                                   ...
# 320681              Spearmint sans sucres
# 320736                            Attiéké
# 320758                   Miel de Camargue
# 320761          Roussette du Bugey (2011)
# 320763                 Thé vert Earl grey
#
# [35252 rows x 2 columns]

# %% [markdown]
# #### La variable product_name contient plus d'informations non null que la colonne generic_name, conservation de product_name

# %%
data_fr_retained.drop('generic_name', axis=1, inplace=True)

# %%
# Afficher le nombre de valeurs manquantes par colonne
data_fr_retained.apply(lambda x: sum(x.isnull()), axis=0).sort_values(ascending=False)
# Out:
# additives_tags             67984
# additives_fr               67984
# labels                     63339
# labels_tags                63301
# labels_fr                  63301
# stores                     60400
# purchase_places            55088
# fiber_100g                 52717
# carbohydrates_100g         51229
# fat_100g                   50798
# ingredients_text           44974
# nutrition_grade_fr         37025
# nutrition_score_fr_100g    37025
# nutrition_score_uk_100g    37025
# categories_fr              36485
# main_category_fr           36485
# categories                 36485
# categories_tags            36485
# main_category              36485
# saturated_fat_100g         36065
# sugars_100g                35925
# sodium_100g                35869
# salt_100g                  35866
# proteins_100g              34122
# energy_100g                33847
# pnns_groups_1              33559
# pnns_groups_2              31402
# brands_tags                12018
# brands                     12014
# product_name                7193
# url                            0
# dtype: int64

# %%
# pourcentage des valeurs manquantes
nan_tot =  data_fr_retained.isna().sum().sum()
data_tot = np.product(data_fr_retained.shape)
percentage = round((nan_tot / data_tot) * 100, 2)
print(f'Valeurs manquantes :{nan_tot} NaN pour {data_tot} données ({percentage} %)')
# Out:
# Valeurs manquantes :1242495 NaN pour 3051640 données (40.72 %)

# %% [markdown]
# ## Transformation des types object en category si le nombre ede modalite est inf au nombre de ligne

# %%
for col in data_fr_retained.columns.values:
    if data_fr_retained[col].dtype == 'object':
        #print(data_fr_retained[col].unique())
        print('Colonne : ', col)
        if len(data_fr_retained[col].unique()) / len(data_fr_retained[col]) < 0.5:
            data_fr_retained[col] = data_fr_retained[col].astype('category')
# Out:
# Colonne :  url
# Colonne :  product_name
# Colonne :  brands
# Colonne :  brands_tags
# Colonne :  categories
# Colonne :  categories_tags
# Colonne :  categories_fr
# Colonne :  labels
# Colonne :  labels_tags
# Colonne :  labels_fr
# Colonne :  purchase_places
# Colonne :  stores
# Colonne :  ingredients_text
# Colonne :  additives_tags
# Colonne :  additives_fr
# Colonne :  nutrition_grade_fr
# Colonne :  pnns_groups_1
# Colonne :  pnns_groups_2
# Colonne :  main_category
# Colonne :  main_category_fr

# %%
data_fr_retained.dtypes
# Out:
# url                          object
# product_name                 object
# brands                     category
# brands_tags                category
# categories                 category
# categories_tags            category
# categories_fr              category
# labels                     category
# labels_tags                category
# labels_fr                  category
# purchase_places            category
# stores                     category
# ingredients_text           category
# additives_tags             category
# additives_fr               category
# nutrition_grade_fr         category
# pnns_groups_1              category
# pnns_groups_2              category
# main_category              category
# main_category_fr           category
# energy_100g                 float64
# fat_100g                    float64
# saturated_fat_100g          float64
# carbohydrates_100g          float64
# sugars_100g                 float64
# fiber_100g                  float64
# proteins_100g               float64
# salt_100g                   float64
# sodium_100g                 float64
# nutrition_score_fr_100g     float64
# nutrition_score_uk_100g     float64
# dtype: object

# %% [markdown]
# ## Suppression des produits sans noms

# %%
data_fr_retained.dropna(subset=['product_name'], inplace=True)

# %%
data_fr_retained_shape = data_fr_retained.shape
print(f"Le jeu de donnee contient {data_fr_retained_shape[0]} lignes et {data_fr_retained_shape[1]} colonnes.")
# Out:
# Le jeu de donnee contient 91247 lignes et 31 colonnes.

# %%
data_fr_retained.columns.tolist()
# Out:
# ['url',
#  'product_name',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_fr',
#  'labels',
#  'labels_tags',
#  'labels_fr',
#  'purchase_places',
#  'stores',
#  'ingredients_text',
#  'additives_tags',
#  'additives_fr',
#  'nutrition_grade_fr',
#  'pnns_groups_1',
#  'pnns_groups_2',
#  'main_category',
#  'main_category_fr',
#  'energy_100g',
#  'fat_100g',
#  'saturated_fat_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  'fiber_100g',
#  'proteins_100g',
#  'salt_100g',
#  'sodium_100g',
#  'nutrition_score_fr_100g',
#  'nutrition_score_uk_100g']

# %%
# Remplacement des tirets '-' dans le groupe par un esapce simple
data_fr_retained['pnns_groups_1'] = data_fr_retained['pnns_groups_1'].str.replace('-', " ")

# %%
# Normaliser tout en minuscule
data_fr_retained['pnns_groups_1'] = data_fr_retained['pnns_groups_1'].str.lower().apply(str)

# %%
data_fr_retained['pnns_groups_1'].sort_values().unique().tolist()
# Out:
# ['beverages',
#  'cereals and potatoes',
#  'composite foods',
#  'fat and sauces',
#  'fish meat eggs',
#  'fruits and vegetables',
#  'milk and dairy products',
#  'nan',
#  'salty snacks',
#  'sugary snacks',
#  'unknown']

# %%
# Traduction de certains nom de groupe en Francais
dico_trad_grp1 = {'beverages': 'boissons',
                  'cereals and potatoes': 'cereales et pommes de terre',
                  'composite foods': 'aliments composes',
                  'fat and sauces': 'matieres grasses et les sauces',
                  'fish meat eggs': 'poisson viande oeufs',
                  'fruits and vegetables': 'fruits et legumes',
                  'milk and dairy products': 'lait et les produits laitiers',
                  'nan': 'a renseigner',
                  'salty snacks': 'collation sales',
                  'sugary snacks': 'collation sucree',
                  'unknown': 'a renseigner'}

for cle, valeur in dico_trad_grp1.items():
    data_fr_retained['pnns_groups_1'] = data_fr_retained['pnns_groups_1'].replace(cle, valeur)

# %%
data_fr_retained['pnns_groups_1'].sort_values().unique().tolist()
# Out:
# ['a renseigner',
#  'aliments composes',
#  'boissons',
#  'cereales et pommes de terre',
#  'collation sales',
#  'collation sucree',
#  'fruits et legumes',
#  'lait et les produits laitiers',
#  'matieres grasses et les sauces',
#  'poisson viande oeufs']

# %%
# Meme chose pour le sous groupe de produit pnns_groups_2
data_fr_retained['pnns_groups_2'] = data_fr_retained['pnns_groups_2'].str.replace('-', " ")

# %%
data_fr_retained['pnns_groups_2'] = data_fr_retained['pnns_groups_2'].str.lower().apply(str)

# %%
data_fr_retained['pnns_groups_2'].unique().tolist()
# Out:
# ['nan',
#  'unknown',
#  'legumes',
#  'biscuits and cakes',
#  'non sugared beverages',
#  'sweetened beverages',
#  'meat',
#  'one dish meals',
#  'soups',
#  'chocolate products',
#  'cheese',
#  'sweets',
#  'sandwich',
#  'appetizers',
#  'dressings and sauces',
#  'dried fruits',
#  'nuts',
#  'breakfast cereals',
#  'pizza pies and quiche',
#  'fruits',
#  'fruit juices',
#  'fats',
#  'alcoholic beverages',
#  'cereals',
#  'vegetables',
#  'bread',
#  'processed meat',
#  'ice cream',
#  'fish and seafood',
#  'pastries',
#  'milk and yogurt',
#  'dairy desserts',
#  'tripe dishes',
#  'artificially sweetened beverages',
#  'fruit nectars',
#  'potatoes',
#  'eggs',
#  'salty and fatty products']

# %%
dico_trad_grp2 = {'alcoholic beverages': 'boissons alcoolisees',
                  'appetizers': 'aperitifs',
                  'artificially sweetened beverages': 'boissons sucrees artificiellement',
                  'biscuits and cakes': 'biscuits et gateaux',
                  'bread': 'pain',
                  'breakfast cereals': 'cereales pour le petit dejeuner',
                  'cereals': 'cereales',
                  'cheese': 'fromage',
                  'chocolate products': 'produits a base de chocolat',
                  'dairy desserts': 'desserts laitiers',
                  'dressings and sauces': 'vinaigrettes et sauces',
                  'dried fruits': 'fruits secs',
                  'eggs': 'oeufs',
                  'fats': 'matieres grasses',
                  'fish and seafood': 'poissons et fruits de mer',
                  'fruit juices': 'jus de fruits',
                  'fruit nectars': 'nectars de fruits',
                  'ice cream': 'glaces',
                  'legumes': 'legumineuses',
                  'meat': 'viande',
                  'milk and yogurt': 'lait et yaourt',
                  'nan': 'a renseigner',
                  'nuts': 'noix',
                  'offals': 'abats',
                  'one-dish meals': 'repas a un plat',
                  'pastries': 'patisseries',
                  'pizza pies and quiches': 'pizzas et quiches',
                  'plant-based milk substitutes': 'substituts de lait a base de plantes',
                  'potatoes': 'pommes de terre',
                  'processed meat': 'viande transformee',
                  'salty and fatty products': 'produits sales et gras',
                  'sandwiches': 'sandwiches',
                  'soups': 'soupes',
                  'sweetened beverages': 'boissons sucrees',
                  'sweets': 'sucreries',
                  'teas and herbal teas and coffees': 'thes tisanes cafes',
                  'unsweetened beverages': 'boissons non sucrees',
                  'vegetables': 'legumes',
                  'waters and flavored waters': 'eaux et eaux aromatisees',
                  'unknown': 'a renseigner'}

for cle, val in dico_trad_grp2.items():
    data_fr_retained['pnns_groups_2'] = data_fr_retained['pnns_groups_2'].replace(cle, val)

# %%
data_fr_retained.columns.tolist()
# Out:
# ['url',
#  'product_name',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_fr',
#  'labels',
#  'labels_tags',
#  'labels_fr',
#  'purchase_places',
#  'stores',
#  'ingredients_text',
#  'additives_tags',
#  'additives_fr',
#  'nutrition_grade_fr',
#  'pnns_groups_1',
#  'pnns_groups_2',
#  'main_category',
#  'main_category_fr',
#  'energy_100g',
#  'fat_100g',
#  'saturated_fat_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  'fiber_100g',
#  'proteins_100g',
#  'salt_100g',
#  'sodium_100g',
#  'nutrition_score_fr_100g',
#  'nutrition_score_uk_100g']

# %%
data_fr_retained.dropna(subset=['product_name', 'energy_100g', 'nutrition_score_fr_100g'], inplace=True)
data_fr_retained.shape
# Out:
# (60992, 31)

# %%
data_fr_retained_shape = data_fr_retained.shape
print(f"Le jeu de donnee contient {data_fr_retained_shape[0]} lignes et {data_fr_retained_shape[1]} colonnes.")
# Out:
# Le jeu de donnee contient 60992 lignes et 31 colonnes.

# %%
# Afficher le nombre de valeurs manquantes par colonne
data_fr_retained.apply(lambda x: sum(x.isnull()), axis=0).sort_values(ascending=False)
# Out:
# additives_fr               35487
# additives_tags             35487
# labels                     33634
# labels_tags                33599
# labels_fr                  33599
# stores                     31588
# purchase_places            28283
# ingredients_text           20133
# carbohydrates_100g         17161
# fat_100g                   17109
# categories_fr              16687
# categories_tags            16687
# categories                 16687
# main_category              16687
# main_category_fr           16687
# fiber_100g                 16414
# brands_tags                  210
# brands                       210
# sugars_100g                    0
# nutrition_score_fr_100g        0
# sodium_100g                    0
# salt_100g                      0
# proteins_100g                  0
# url                            0
# nutrition_grade_fr             0
# saturated_fat_100g             0
# energy_100g                    0
# pnns_groups_2                  0
# pnns_groups_1                  0
# product_name                   0
# nutrition_score_uk_100g        0
# dtype: int64

# %%
data_fr_retained.describe(include='all')
# Out:
#                                                       url product_name  \
# count                                               60992        60992
# unique                                              60992        51066
# top     http://world-fr.openfoodfacts.org/produit/0000...   Mayonnaise
# freq                                                    1           43
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#            brands brands_tags                                  categories  \
# count       60782       60782                                       44305
# unique      12732        9973                                       19464
# top     Carrefour   carrefour  Snacks sucrés,Biscuits et gâteaux,Biscuits
# freq         2313        2354                                         259
# mean          NaN         NaN                                         NaN
# std           NaN         NaN                                         NaN
# min           NaN         NaN                                         NaN
# 25%           NaN         NaN                                         NaN
# 50%           NaN         NaN                                         NaN
# 75%           NaN         NaN                                         NaN
# max           NaN         NaN                                         NaN
#
#                                           categories_tags  \
# count                                               44305
# unique                                              11612
# top     en:sugary-snacks,en:biscuits-and-cakes,en:bisc...
# freq                                                  488
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                      categories_fr  \
# count                                        44305
# unique                                       11612
# top     Snacks sucrés,Biscuits et gâteaux,Biscuits
# freq                                           488
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#                                                    labels  \
# count                                               27358
# unique                                              10497
# top     Organic, EU Organic, fr:AB Agriculture Biologique
# freq                                                 3220
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               labels_tags  \
# count                                               27393
# unique                                               7839
# top     en:organic,en:eu-organic,fr:ab-agriculture-bio...
# freq                                                 4685
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                          labels_fr  ...      fat_100g  \
# count                                        27393  ...  43883.000000
# unique                                        7839  ...           NaN
# top     Bio,Bio européen,AB Agriculture Biologique  ...           NaN
# freq                                          4685  ...           NaN
# mean                                           NaN  ...     13.334119
# std                                            NaN  ...     16.767690
# min                                            NaN  ...      0.000000
# 25%                                            NaN  ...      1.400000
# 50%                                            NaN  ...      7.000000
# 75%                                            NaN  ...     21.000000
# max                                            NaN  ...    380.000000
#
#        saturated_fat_100g carbohydrates_100g   sugars_100g    fiber_100g  \
# count        60992.000000       43831.000000  60992.000000  44578.000000
# unique                NaN                NaN           NaN           NaN
# top                   NaN                NaN           NaN           NaN
# freq                  NaN                NaN           NaN           NaN
# mean             5.439707          27.787834     13.389663      2.542348
# std              8.561807          27.275458     19.020091      4.621375
# min              0.000000           0.000000     -0.100000      0.000000
# 25%              0.300000           4.100000      1.000000      0.000000
# 50%              2.000000          14.800000      4.000000      1.300000
# 75%              7.400000          53.000000     17.870000      3.200000
# max            210.000000         190.000000    104.000000    178.000000
#
#        proteins_100g     salt_100g   sodium_100g nutrition_score_fr_100g  \
# count   60992.000000  60992.000000  60992.000000            60992.000000
# unique           NaN           NaN           NaN                     NaN
# top              NaN           NaN           NaN                     NaN
# freq             NaN           NaN           NaN                     NaN
# mean        7.748720      1.082642      0.426237                8.690107
# std         7.845984      3.815873      1.502264                9.044649
# min         0.000000      0.000000      0.000000              -15.000000
# 25%         1.900000      0.080000      0.031496                1.000000
# 50%         6.000000      0.551180      0.217000                9.000000
# 75%        10.900000      1.230000      0.484252               15.000000
# max       100.000000    211.000000     83.000000               40.000000
#
#        nutrition_score_uk_100g
# count             60992.000000
# unique                     NaN
# top                        NaN
# freq                       NaN
# mean                  8.369180
# std                   9.384286
# min                 -15.000000
# 25%                   0.000000
# 50%                   7.000000
# 75%                  16.000000
# max                  36.000000
#
# [11 rows x 31 columns]

# %%
# Remplacement des valeurs restantes
data_fr_completed = data_fr_retained.fillna(np.NaN)

data_fr_completed_shape = data_fr_completed.shape
print(f"Le jeu de donnee contient {data_fr_completed_shape[0]} lignes et {data_fr_completed_shape[1]} colonnes.")
# Out:
# Le jeu de donnee contient 60992 lignes et 31 colonnes.

# %% [markdown]
# ## Correction des valeurs aberrantes

# %%
# Suppression si energy_100g > 900 calories
# car les lipides sont les nutriments les plus denses et 100g de lipides = 900 calories

data_fr_completed.drop(data_fr_completed[data_fr_completed.energy_100g > 900].index, inplace=True)

# %%
# Suppression si valeurs nutritionnelles (pour 100g) > 100g ou < 0g
for col in data_fr_completed.columns[data_fr_completed.columns.str.endswith('_100g')]:
    data_fr_completed.drop(data_fr_completed[(data_fr_completed[col] > 100) | (data_fr_completed[col] < 0)].index, inplace=True)

# %%
# Suppresion si somme des glucides + lipides + protéines + sel pour 100g > 100g (à 10% près)
data_fr_completed['temp'] = (data_fr_completed[['fat_100g', 'saturated_fat_100g']].fillna(0).max(axis=1)
               + data_fr_completed[['carbohydrates_100g', 'sugars_100g']].fillna(0).max(axis=1)
               + data_fr_completed['proteins_100g'].fillna(0)
               + data_fr_completed['fiber_100g'].fillna(0)
               + data_fr_completed['salt_100g'].fillna(0))
data_fr_completed.drop(data_fr_completed[data_fr_completed['temp'] > 110].index, inplace=True)

# %%
# Suppression si calories < lipides*9 + (glucides+proteines)*4 + fibres*1.9 (à 10% près)
data_fr_completed['temp'] = (9*data_fr_completed['fat_100g'].fillna(0)
               + 4*(data_fr_completed['carbohydrates_100g'].fillna(0) + data_fr_completed['proteins_100g'].fillna(0))
               + 1.9*data_fr_completed['fiber_100g'].fillna(0))
data_fr_completed.drop(data_fr_completed[data_fr_completed['temp'] > 1.1 * data_fr_completed['energy_100g']].index, inplace=True)

# %%
# Suppression si calories > lipides*9 + (glucides+proteines)*4 + fibres*1.9 (à 10% près)
# SI toutes les infos sur les nutriments sont dispos
mask = (~(data_fr_completed['fat_100g'].isnull()
          | data_fr_completed['carbohydrates_100g'].isnull()
          | data_fr_completed['fiber_100g'].isnull())
        & (data_fr_completed['energy_100g'] > 1.1 * data_fr_completed['temp']))
data_fr_completed.drop(data_fr_completed[mask].index, inplace=True)
data_fr_completed.drop(['temp'], axis=1, inplace=True)

data_fr_completed.shape
# Out:
# (7957, 31)

# %%
data_fr_completed.describe(include='all')
# Out:
#                                                       url      product_name  \
# count                                                7957              7957
# unique                                               7957              6876
# top     http://world-fr.openfoodfacts.org/produit/0000...  Lait demi-écrémé
# freq                                                    1                25
# mean                                                  NaN               NaN
# std                                                   NaN               NaN
# min                                                   NaN               NaN
# 25%                                                   NaN               NaN
# 50%                                                   NaN               NaN
# 75%                                                   NaN               NaN
# max                                                   NaN               NaN
#
#        brands brands_tags           categories  \
# count    7938        7938                 5520
# unique   2589        2139                 2838
# top         U      auchan  Boissons aux fruits
# freq      237         244                  102
# mean      NaN         NaN                  NaN
# std       NaN         NaN                  NaN
# min       NaN         NaN                  NaN
# 25%       NaN         NaN                  NaN
# 50%       NaN         NaN                  NaN
# 75%       NaN         NaN                  NaN
# max       NaN         NaN                  NaN
#
#                                           categories_tags  \
# count                                                5520
# unique                                               1859
# top     en:beverages,en:carbonated-drinks,en:sodas,en:...
# freq                                                  117
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                             categories_fr  \
# count                                                5520
# unique                                               1859
# top     Boissons,Boissons gazeuses,Sodas,Sodas au cola...
# freq                                                  117
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    labels  \
# count                                                3484
# unique                                               1742
# top     Organic, EU Organic, fr:AB Agriculture Biologique
# freq                                                  522
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               labels_tags  \
# count                                                3485
# unique                                               1379
# top     en:organic,en:eu-organic,fr:ab-agriculture-bio...
# freq                                                  737
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                          labels_fr  ...     fat_100g  \
# count                                         3485  ...  5220.000000
# unique                                        1379  ...          NaN
# top     Bio,Bio européen,AB Agriculture Biologique  ...          NaN
# freq                                           737  ...          NaN
# mean                                           NaN  ...     1.568744
# std                                            NaN  ...     1.721604
# min                                            NaN  ...     0.000000
# 25%                                            NaN  ...     0.000000
# 50%                                            NaN  ...     1.100000
# 75%                                            NaN  ...     2.700000
# max                                            NaN  ...    10.600000
#
#        saturated_fat_100g carbohydrates_100g  sugars_100g   fiber_100g  \
# count         7957.000000        5228.000000  7957.000000  5833.000000
# unique                NaN                NaN          NaN          NaN
# top                   NaN                NaN          NaN          NaN
# freq                  NaN                NaN          NaN          NaN
# mean             0.755978           7.555752     6.319379     0.620151
# std              1.612437           4.609548     5.801604     1.008501
# min              0.000000           0.000000     0.000000     0.000000
# 25%              0.000000           4.500000     1.700000     0.000000
# 50%              0.200000           6.900000     5.000000     0.100000
# 75%              1.000000          11.100000    10.500000     1.000000
# max             55.000000          23.700000   100.000000    33.000000
#
#        proteins_100g    salt_100g  sodium_100g nutrition_score_fr_100g  \
# count    7957.000000  7957.000000  7957.000000             7957.000000
# unique           NaN          NaN          NaN                     NaN
# top              NaN          NaN          NaN                     NaN
# freq             NaN          NaN          NaN                     NaN
# mean        2.333962     1.255249     0.494194                4.308282
# std         3.680309     7.635214     3.006010                4.926340
# min         0.000000     0.000000     0.000000                0.000000
# 25%         0.200000     0.012700     0.005000                1.000000
# 50%         1.100000     0.120000     0.047244                2.000000
# 75%         3.200000     0.762000     0.300000                6.000000
# max        26.000000   100.000000    39.370079               30.000000
#
#        nutrition_score_uk_100g
# count              7957.000000
# unique                     NaN
# top                        NaN
# freq                       NaN
# mean                  2.091869
# std                   2.537597
# min                   0.000000
# 25%                   0.000000
# 50%                   1.000000
# 75%                   3.000000
# max                  25.000000
#
# [11 rows x 31 columns]

# %% [markdown]
# ## Traitement des colonnes semblables

# %%
categories = data_fr_completed[['categories', 'categories_tags', 'categories_fr', 'pnns_groups_1', 'pnns_groups_2', 'main_category', 'main_category_fr']]

# %%
print("Nombre de catégories différentes:")
for col in categories:
    print(f"{col} : {len(categories[col].value_counts())}")
# Out:
# Nombre de catégories différentes:
# categories : 26653
# categories_tags : 15640
# categories_fr : 15640
# pnns_groups_1 : 10
# pnns_groups_2 : 26
# main_category : 1615
# main_category_fr : 1615

# %% [markdown]
# #### 'pnns_groups_1' semble être le meilleur choix avec un nombre de catégories plus réduit, ce qui permettra éventuellement de faire des analyses dessus

# %%
data_fr_completed['pnns_groups_1'].value_counts()
# Out:
# pnns_groups_1
# a renseigner                      2934
# boissons                          2025
# lait et les produits laitiers     1096
# aliments composes                  563
# fruits et legumes                  487
# matieres grasses et les sauces     469
# poisson viande oeufs               207
# cereales et pommes de terre        132
# collation sucree                    38
# collation sales                      6
# Name: count, dtype: int64

# %% [markdown]
# ### Nouvelle reduction des variables a conserver

# %%
data_fr_completed.drop(['categories', 'categories_tags', 'categories_fr', 'pnns_groups_2', 'main_category', 'main_category_fr'], axis=1, inplace=True)

data_fr_completed_shape = data_fr_completed.shape
print(f"Le jeu de donnee contient {data_fr_completed_shape[0]} lignes et {data_fr_completed_shape[1]} colonnes.")
# Out:
# Le jeu de donnee contient 7957 lignes et 25 colonnes.

# %% [markdown]
# ## Comparaison du sel VS sodium

# %%
print(f"Corrélation entre 'salt_100g' et 'sodium_100g': {data_fr_completed['salt_100g'].corr(data_fr_completed['sodium_100g'])}")

plt.title('Vérification de la proportionnalité entre le sel et le sodium')
plt.scatter(data_fr_completed['salt_100g'], data_fr_completed['sodium_100g'], color='orange', label='Données réelles')
plt.plot(data_fr_completed['salt_100g'], data_fr_completed['salt_100g'] / 2.54, color='black', label='Droite théorique')
plt.xlabel('Salt_100g')
plt.ylabel('Sodium_100g')
plt.legend(loc='lower right')
plt.show()
# Out:
# Corrélation entre 'salt_100g' et 'sodium_100g': 0.9999999982507681

# %%
# supprimer les produits si 2,54 * sodium > sel (en g).
# Produit avec taux de sodium * 2.5 > taux de sel ?

data_fr_completed.drop(data_fr_completed[data_fr_completed['sodium_100g'] > data_fr_completed['salt_100g']/2.4].index, inplace=True)

# %%
data_fr_completed.columns.tolist()
# Out:
# ['url',
#  'product_name',
#  'brands',
#  'brands_tags',
#  'labels',
#  'labels_tags',
#  'labels_fr',
#  'purchase_places',
#  'stores',
#  'ingredients_text',
#  'additives_tags',
#  'additives_fr',
#  'nutrition_grade_fr',
#  'pnns_groups_1',
#  'energy_100g',
#  'fat_100g',
#  'saturated_fat_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  'fiber_100g',
#  'proteins_100g',
#  'salt_100g',
#  'sodium_100g',
#  'nutrition_score_fr_100g',
#  'nutrition_score_uk_100g']

# %%
mask = data_fr_completed['nutrition_score_fr_100g'] == data_fr_completed['nutrition_score_uk_100g']

print(f"Les 2 scores sont identiques dans "
      f"{len(data_fr_completed[mask])/data_fr_completed.shape[0]*100:.2f}% des cas")
# Out:
# Les 2 scores sont identiques dans 77.13% des cas

# %%
data_fr_completed[~mask]['pnns_groups_1'].value_counts()
# Out:
# pnns_groups_1
# boissons                         1785
# a renseigner                       34
# lait et les produits laitiers       1
# Name: count, dtype: int64

# %% [markdown]
# #### Barème différent sur les boissons, les produits à renseigner et pour un produit aossicé au lait et produits laitiers

# %%
data_fr_completed.drop(['nutrition_score_uk_100g'], axis=1, inplace=True)
data_fr_completed.shape
# Out:
# (7957, 24)

# %% [markdown]
# ## Difference entre brand et brand_tags

# %%
data_fr_completed[['brands', 'brands_tags']].sample(10)
# Out:
#                                                  brands  \
# 238250                                        Carrefour
# 209424                                                U
# 214363                                            Royal
# 228924                                  U,Les Saveurs U
# 239845                                    Carrefour Bio
# 232475                           Lactel,Jour après Jour
# 197742                                           Natali
# 190770                         Blédilait,Blédina,Danone
# 208672  Auchan,L'oiseau,Auchan Production,Groupe Auchan
# 216702                                     Leader Price
#
#                                             brands_tags
# 238250                                        carrefour
# 209424                                                u
# 214363                                            royal
# 228924                                  u,les-saveurs-u
# 239845                                    carrefour-bio
# 232475                           lactel,jour-apres-jour
# 197742                                           natali
# 190770                         bledilait,bledina,danone
# 208672  auchan,l-oiseau,auchan-production,groupe-auchan
# 216702                                     leader-price

# %%
print("Nombre de valeurs manquantes:")
for col in ['brands', 'brands_tags']:
    print(f"{col} : {sum(data_fr_completed[col].isnull())}")
# Out:
# Nombre de valeurs manquantes:
# brands : 19
# brands_tags : 19

# %%
data_fr_completed.drop(['brands_tags'], axis=1, inplace=True)
data_fr_completed.shape
# Out:
# (7957, 23)

# %% [markdown]
# ## Verification des valeurs manquantes après les corrections

# %%
values = data_fr_completed.isnull().sum()
percentage = 100 * values / len(data_fr_completed)
table = pd.concat([values, percentage.round(2)], axis=1)
table.columns = ['Nombres de valeurs manquantes', '% de valeurs manquantes']
table.loc[table['Nombres de valeurs manquantes'] != 0].sort_values('% de valeurs manquantes', ascending=False).style.background_gradient('Greens')
# Out:
# <style type="text/css">
# #T_3d5e9_row0_col0, #T_3d5e9_row0_col1, #T_3d5e9_row1_col0, #T_3d5e9_row1_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_3d5e9_row2_col0, #T_3d5e9_row2_col1 {
#   background-color: #006027;
#   color: #f1f1f1;
# }
# #T_3d5e9_row3_col0, #T_3d5e9_row3_col1, #T_3d5e9_row4_col0, #T_3d5e9_row4_col1, #T_3d5e9_row5_col0, #T_3d5e9_row5_col1 {
#   background-color: #006729;
#   color: #f1f1f1;
# }
# #T_3d5e9_row6_col0, #T_3d5e9_row6_col1 {
#   background-color: #0e7936;
#   color: #f1f1f1;
# }
# #T_3d5e9_row7_col0, #T_3d5e9_row7_col1 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_3d5e9_row8_col0, #T_3d5e9_row8_col1 {
#   background-color: #62bb6d;
#   color: #f1f1f1;
# }
# #T_3d5e9_row9_col0, #T_3d5e9_row9_col1 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_3d5e9_row10_col0, #T_3d5e9_row10_col1 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_3d5e9_row11_col0, #T_3d5e9_row11_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_3d5e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d5e9_level0_col0" class="col_heading level0 col0" >Nombres de valeurs manquantes</th>
#       <th id="T_3d5e9_level0_col1" class="col_heading level0 col1" >% de valeurs manquantes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d5e9_level0_row0" class="row_heading level0 row0" >additives_tags</th>
#       <td id="T_3d5e9_row0_col0" class="data row0 col0" >5012</td>
#       <td id="T_3d5e9_row0_col1" class="data row0 col1" >62.990000</td>
#     </tr>
#     <tr>
#       <th id="T_3d5e9_level0_row1" class="row_heading level0 row1" >additives_fr</th>
#       <td id="T_3d5e9_row1_col0" class="data row1 col0" >5012</td>
#       <td id="T_3d5e9_row1_col1" class="data row1 col1" >62.990000</td>
#     </tr>
#     <tr>
#       <th id="T_3d5e9_level0_row2" class="row_heading level0 row2" >stores</th>
#       <td id="T_3d5e9_row2_col0" class="data row2 col0" >4570</td>
#       <td id="T_3d5e9_row2_col1" class="data row2 col1" >57.430000</td>
#     </tr>
#     <tr>
#       <th id="T_3d5e9_level0_row3" class="row_heading level0 row3" >labels</th>
#       <td id="T_3d5e9_row3_col0" class="data row3 col0" >4473</td>
#       <td id="T_3d5e9_row3_col1" class="data row3 col1" >56.210000</td>
#     </tr>
#     <tr>
#       <th id="T_3d5e9_level0_row4" class="row_heading level0 row4" >labels_tags</th>
#       <td id="T_3d5e9_row4_col0" class="data row4 col0" >4472</td>
#       <td id="T_3d5e9_row4_col1" class="data row4 col1" >56.200000</td>
#     </tr>
#     <tr>
#       <th id="T_3d5e9_level0_row5" class="row_heading level0 row5" >labels_fr</th>
#       <td id="T_3d5e9_row5_col0" class="data row5 col0" >4472</td>
#       <td id="T_3d5e9_row5_col1" class="data row5 col1" >56.200000</td>
#     </tr>
#     <tr>
#       <th id="T_3d5e9_level0_row6" class="row_heading level0 row6" >purchase_places</th>
#       <td id="T_3d5e9_row6_col0" class="data row6 col0" >4127</td>
#       <td id="T_3d5e9_row6_col1" class="data row6 col1" >51.870000</td>
#     </tr>
#     <tr>
#       <th id="T_3d5e9_level0_row7" class="row_heading level0 row7" >ingredients_text</th>
#       <td id="T_3d5e9_row7_col0" class="data row7 col0" >3103</td>
#       <td id="T_3d5e9_row7_col1" class="data row7 col1" >39.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d5e9_level0_row8" class="row_heading level0 row8" >fat_100g</th>
#       <td id="T_3d5e9_row8_col0" class="data row8 col0" >2737</td>
#       <td id="T_3d5e9_row8_col1" class="data row8 col1" >34.400000</td>
#     </tr>
#     <tr>
#       <th id="T_3d5e9_level0_row9" class="row_heading level0 row9" >carbohydrates_100g</th>
#       <td id="T_3d5e9_row9_col0" class="data row9 col0" >2729</td>
#       <td id="T_3d5e9_row9_col1" class="data row9 col1" >34.300000</td>
#     </tr>
#     <tr>
#       <th id="T_3d5e9_level0_row10" class="row_heading level0 row10" >fiber_100g</th>
#       <td id="T_3d5e9_row10_col0" class="data row10 col0" >2124</td>
#       <td id="T_3d5e9_row10_col1" class="data row10 col1" >26.690000</td>
#     </tr>
#     <tr>
#       <th id="T_3d5e9_level0_row11" class="row_heading level0 row11" >brands</th>
#       <td id="T_3d5e9_row11_col0" class="data row11 col0" >19</td>
#       <td id="T_3d5e9_row11_col1" class="data row11 col1" >0.240000</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("-------------------------------------------------------------")
print("Heatmap de visualisation des valeurs manquantes")
plt.figure(figsize=(20, 10))
sns.heatmap(data_fr_completed.isna(), cbar=False)
plt.show()
# Out:
# -------------------------------------------------------------
# Heatmap de visualisation des valeurs manquantes

# %% [markdown]
# ### Passage sur les variables qualitatives

# %%
data_fr_completed['nutrition_grade_fr'].unique()
# Out:
# ['e', 'b', 'c', 'a', 'd']
# Categories (5, object): ['a', 'b', 'c', 'd', 'e']

# %%
data_fr_completed['nutrition_grade_fr'] = data_fr_completed['nutrition_grade_fr'].str.upper().apply(str)

# %%
data_fr_completed['nutrition_grade_fr'].unique()
# Out:
# array(['E', 'B', 'C', 'A', 'D'], dtype=object)

# %%
# Préparation des variables de travail pour les graphiques et les tests
gb = data_fr_completed.groupby('nutrition_grade_fr')['nutrition_score_fr_100g']
df_nutriscore = pd.DataFrame([gb.get_group(n).values for n in list('ABCDE')], index=list('ABCDE')).T

# %%
df_nutriscore
# Out:
#         A    B    C     D     E
# 0     0.0  1.0  4.0  11.0  13.0
# 1     0.0  2.0  5.0  13.0  13.0
# 2     0.0  0.0  6.0  12.0  12.0
# 3     0.0  0.0  3.0  13.0  18.0
# 4     0.0  1.0  6.0   6.0  15.0
# ...   ...  ...  ...   ...   ...
# 4088  NaN  1.0  NaN   NaN   NaN
# 4089  NaN  0.0  NaN   NaN   NaN
# 4090  NaN  0.0  NaN   NaN   NaN
# 4091  NaN  1.0  NaN   NaN   NaN
# 4092  NaN  0.0  NaN   NaN   NaN
#
# [4093 rows x 5 columns]

# %%
def stat_descriptives(dataframe, liste_variables):
    """
    Statistiques descriptives moyenne, mediane, variance, écart-type,
    skewness et kurtosis du dataframe transmis en paramètre
    ----------
    @param IN : dataframe : DataFrame, obligatoire
                liste_variables : colonne dont on veut voir les stat descr
    @param OUT : dataframe des statistiques descriptives
    """
    liste_mean = ['mean']
    liste_median = ['median']
    liste_var = ['var']
    liste_std = ['std']
    liste_skew = ['skew']
    liste_kurtosis = ['kurtosis']
    liste_mode = ['mode']
    liste_cols = ['Desc']
    liste_max = ['Max']
    liste_min = ['Min']

    for col in liste_variables:
        liste_mean.append(dataframe[col].mean())
        liste_median.append(dataframe[col].median())
        liste_var.append(dataframe[col].var(ddof=0))
        liste_std.append(dataframe[col].std(ddof=0))
        liste_skew.append(dataframe[col].skew())
        liste_kurtosis.append(dataframe[col].kurtosis())
        liste_cols.append(col)
        liste_mode.append(dataframe[col].mode().to_string())
        liste_min.append(dataframe[col].min())
        liste_max.append(dataframe[col].max())

    data_stats = [liste_mean, liste_median, liste_var, liste_std, liste_skew, liste_kurtosis, liste_mode, liste_min, liste_max]
    df_stat = pd.DataFrame(data_stats, columns=liste_cols)

    return df_stat.style.hide()

# %%
stat_descriptives(df_nutriscore, ['A', 'B', 'C', 'D', 'E'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_d71e9">
#   <thead>
#     <tr>
#       <th id="T_d71e9_level0_col0" class="col_heading level0 col0" >Desc</th>
#       <th id="T_d71e9_level0_col1" class="col_heading level0 col1" >A</th>
#       <th id="T_d71e9_level0_col2" class="col_heading level0 col2" >B</th>
#       <th id="T_d71e9_level0_col3" class="col_heading level0 col3" >C</th>
#       <th id="T_d71e9_level0_col4" class="col_heading level0 col4" >D</th>
#       <th id="T_d71e9_level0_col5" class="col_heading level0 col5" >E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d71e9_row0_col0" class="data row0 col0" >mean</td>
#       <td id="T_d71e9_row0_col1" class="data row0 col1" >0.425000</td>
#       <td id="T_d71e9_row0_col2" class="data row0 col2" >0.884681</td>
#       <td id="T_d71e9_row0_col3" class="data row0 col3" >4.374401</td>
#       <td id="T_d71e9_row0_col4" class="data row0 col4" >9.003650</td>
#       <td id="T_d71e9_row0_col5" class="data row0 col5" >13.936134</td>
#     </tr>
#     <tr>
#       <td id="T_d71e9_row1_col0" class="data row1 col0" >median</td>
#       <td id="T_d71e9_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_d71e9_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_d71e9_row1_col3" class="data row1 col3" >4.000000</td>
#       <td id="T_d71e9_row1_col4" class="data row1 col4" >9.000000</td>
#       <td id="T_d71e9_row1_col5" class="data row1 col5" >14.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d71e9_row2_col0" class="data row2 col0" >var</td>
#       <td id="T_d71e9_row2_col1" class="data row2 col1" >1.344375</td>
#       <td id="T_d71e9_row2_col2" class="data row2 col2" >0.648319</td>
#       <td id="T_d71e9_row2_col3" class="data row2 col3" >4.124925</td>
#       <td id="T_d71e9_row2_col4" class="data row2 col4" >5.525534</td>
#       <td id="T_d71e9_row2_col5" class="data row2 col5" >6.527014</td>
#     </tr>
#     <tr>
#       <td id="T_d71e9_row3_col0" class="data row3 col0" >std</td>
#       <td id="T_d71e9_row3_col1" class="data row3 col1" >1.159472</td>
#       <td id="T_d71e9_row3_col2" class="data row3 col2" >0.805183</td>
#       <td id="T_d71e9_row3_col3" class="data row3 col3" >2.030991</td>
#       <td id="T_d71e9_row3_col4" class="data row3 col4" >2.350645</td>
#       <td id="T_d71e9_row3_col5" class="data row3 col5" >2.554802</td>
#     </tr>
#     <tr>
#       <td id="T_d71e9_row4_col0" class="data row4 col0" >skew</td>
#       <td id="T_d71e9_row4_col1" class="data row4 col1" >3.690196</td>
#       <td id="T_d71e9_row4_col2" class="data row4 col2" >0.211767</td>
#       <td id="T_d71e9_row4_col3" class="data row4 col3" >1.480525</td>
#       <td id="T_d71e9_row4_col4" class="data row4 col4" >0.884846</td>
#       <td id="T_d71e9_row4_col5" class="data row4 col5" >0.922899</td>
#     </tr>
#     <tr>
#       <td id="T_d71e9_row5_col0" class="data row5 col0" >kurtosis</td>
#       <td id="T_d71e9_row5_col1" class="data row5 col1" >14.642490</td>
#       <td id="T_d71e9_row5_col2" class="data row5 col2" >-1.428410</td>
#       <td id="T_d71e9_row5_col3" class="data row5 col3" >1.476066</td>
#       <td id="T_d71e9_row5_col4" class="data row5 col4" >0.792634</td>
#       <td id="T_d71e9_row5_col5" class="data row5 col5" >2.685412</td>
#     </tr>
#     <tr>
#       <td id="T_d71e9_row6_col0" class="data row6 col0" >mode</td>
#       <td id="T_d71e9_row6_col1" class="data row6 col1" >0    0.0</td>
#       <td id="T_d71e9_row6_col2" class="data row6 col2" >0    0.0</td>
#       <td id="T_d71e9_row6_col3" class="data row6 col3" >0    3.0</td>
#       <td id="T_d71e9_row6_col4" class="data row6 col4" >0    9.0</td>
#       <td id="T_d71e9_row6_col5" class="data row6 col5" >0    13.0</td>
#     </tr>
#     <tr>
#       <td id="T_d71e9_row7_col0" class="data row7 col0" >Min</td>
#       <td id="T_d71e9_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_d71e9_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_d71e9_row7_col3" class="data row7 col3" >2.000000</td>
#       <td id="T_d71e9_row7_col4" class="data row7 col4" >6.000000</td>
#       <td id="T_d71e9_row7_col5" class="data row7 col5" >10.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d71e9_row8_col0" class="data row8 col0" >Max</td>
#       <td id="T_d71e9_row8_col1" class="data row8 col1" >6.000000</td>
#       <td id="T_d71e9_row8_col2" class="data row8 col2" >2.000000</td>
#       <td id="T_d71e9_row8_col3" class="data row8 col3" >10.000000</td>
#       <td id="T_d71e9_row8_col4" class="data row8 col4" >18.000000</td>
#       <td id="T_d71e9_row8_col5" class="data row8 col5" >30.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
cond1 = data_fr_completed['nutrition_grade_fr'] == 'A'
cond2 = data_fr_completed['nutrition_score_fr_100g'] > 0
data_fr_completed[cond1 & cond2][['product_name', 'nutrition_grade_fr', 'nutrition_score_fr_100g']]
# Out:
#                              product_name nutrition_grade_fr  \
# 192052                Sans sucres Agrumes                  A
# 192065            La Salvetat Citron vert                  A
# 192067                      Badoit Citron                  A
# 192073                   Badoit Framboise                  A
# 192119                 La Salvetat Citron                  A
# 220374  Sémillante arômes naturels Citron                  A
# 245670                     Source St Jean                  A
# 304683                         Courmayeur                  A
#
#         nutrition_score_fr_100g
# 192052                      1.0
# 192065                      1.0
# 192067                      1.0
# 192073                      1.0
# 192119                      1.0
# 220374                      4.0
# 245670                      2.0
# 304683                      6.0

# %%
data_fr_completed_shape = data_fr_completed.shape
print(f"Le jeu de donnee contient {data_fr_completed_shape[0]} lignes et {data_fr_completed_shape[1]} colonnes.")
# Out:
# Le jeu de donnee contient 7957 lignes et 23 colonnes.

# %%
data_fr_completed
# Out:
#                                                       url  \
# 226     http://world-fr.openfoodfacts.org/produit/0000...
# 240     http://world-fr.openfoodfacts.org/produit/0000...
# 493     http://world-fr.openfoodfacts.org/produit/0001...
# 523     http://world-fr.openfoodfacts.org/produit/0002...
# 564     http://world-fr.openfoodfacts.org/produit/0003...
# ...                                                   ...
# 320628  http://world-fr.openfoodfacts.org/produit/9556...
# 320629  http://world-fr.openfoodfacts.org/produit/9556...
# 320649  http://world-fr.openfoodfacts.org/produit/9556...
# 320660  http://world-fr.openfoodfacts.org/produit/9557...
# 320680  http://world-fr.openfoodfacts.org/produit/9606...
#
#                              product_name            brands  \
# 226                 Pepsi, Nouveau goût !             Pepsi
# 240                                   7Up       7Up,Pepsico
# 493               Carrot & Coriander soup               NaN
# 523                        Masala Ketchup  Mark And Spencer
# 564          Pur Soup' Velouté de légumes            Liebig
# ...                                   ...               ...
# 320628      Boisson au soja (soy bean 8%)             Yeo's
# 320629               Yeo's Soy Bean Drink             Yeo's
# 320649          Glinter Soft Drink Lychee           Glinter
# 320660                Lait Soja Brique 1L          Marigold
# 320680  Princes Tuna Chunks In Brine 160G           Princes
#
#                                                    labels  \
# 226                                                   NaN
# 240                                                   NaN
# 493                                                   NaN
# 523                                                   NaN
# 564     Sans colorants,Sans conservateurs,Cuisiné en F...
# ...                                                   ...
# 320628                                                NaN
# 320629         Bio,Bio européen,AB Agriculture Biologique
# 320649                                                NaN
# 320660                                                NaN
# 320680                                                NaN
#
#                                               labels_tags  \
# 226                                                   NaN
# 240                                                   NaN
# 493                                                   NaN
# 523                                                   NaN
# 564     en:no-colorings,en:no-preservatives,fr:cuisine...
# ...                                                   ...
# 320628                                                NaN
# 320629  en:organic,en:eu-organic,fr:ab-agriculture-bio...
# 320649                                                NaN
# 320660                                                NaN
# 320680                                                NaN
#
#                                                 labels_fr    purchase_places  \
# 226                                                   NaN              Avion
# 240                                                   NaN  Courrières,France
# 493                                                   NaN                NaN
# 523                                                   NaN                NaN
# 564     Sans colorants,Sans conservateurs,Cuisine-en-f...          Marseille
# ...                                                   ...                ...
# 320628                                                NaN       Paris France
# 320629         Bio,Bio européen,AB Agriculture Biologique                NaN
# 320649                                                NaN                NaN
# 320660                                                NaN                NaN
# 320680                                                NaN                NaN
#
#                 stores                                   ingredients_text  \
# 226                NaN  Eau gazéifiée, sucre, colorant caramel E150d, ...
# 240     Cora Cafétéria  Eau gazéifiée, sucre, acidifiants (acide citri...
# 493                NaN                                                NaN
# 523                NaN                                                NaN
# 564          U Express  eau, légumes 38% (jus de tomates à base de con...
# ...                ...                                                ...
# 320628     Tang Frères  Eau, extrait de _soja_ (_soja_ 8 %), sucre de ...
# 320629             NaN                                                NaN
# 320649             NaN                                                NaN
# 320660             NaN                                                NaN
# 320680             NaN                                                NaN
#
#                  additives_tags  ... energy_100g fat_100g saturated_fat_100g  \
# 226            en:e150d,en:e338  ...   42.304015      0.0                0.0
# 240     en:e330,en:e296,en:e331  ...   42.304015      0.0                0.0
# 493                         NaN  ...   30.114723      1.4                0.8
# 523                         NaN  ...   96.080306      NaN                0.1
# 564                    en:e160a  ...   44.933078      2.1                0.7
# ...                         ...  ...         ...      ...                ...
# 320628                      NaN  ...   51.147228      1.1                0.2
# 320629                      NaN  ...   53.059273      NaN                0.2
# 320649                      NaN  ...   80.066922      NaN                0.0
# 320660                      NaN  ...   55.927342      NaN                2.0
# 320680                      NaN  ...   98.948375      NaN                0.1
#
#         carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# 226                   10.4         10.4         0.0            0.0     0.0254
# 240                   10.4         10.4         NaN            0.0     0.1000
# 493                    3.6          2.7         1.0            0.3     0.6300
# 523                    NaN         18.0         3.0            1.7     1.2300
# 564                    5.3          2.4         0.8            0.8     0.7500
# ...                    ...          ...         ...            ...        ...
# 320628                 8.1          7.8         0.0            2.0     0.0000
# 320629                 NaN          8.3         0.0            2.0     0.0100
# 320649                 NaN         20.0         0.0            0.0    28.0000
# 320660                 NaN          8.0         0.0            2.0     0.0000
# 320680                 NaN          0.0         0.1           23.5     1.0500
#
#         sodium_100g  nutrition_score_fr_100g
# 226        0.010000                     13.0
# 240        0.039370                     13.0
# 493        0.248031                      1.0
# 523        0.484252                      4.0
# 564        0.295276                      2.0
# ...             ...                      ...
# 320628     0.000000                      0.0
# 320629     0.003937                     14.0
# 320649    11.023622                     14.0
# 320660     0.000000                      1.0
# 320680     0.413386                      0.0
#
# [7957 rows x 23 columns]

# %%
data_fr_completed.columns.tolist()
# Out:
# ['url',
#  'product_name',
#  'brands',
#  'labels',
#  'labels_tags',
#  'labels_fr',
#  'purchase_places',
#  'stores',
#  'ingredients_text',
#  'additives_tags',
#  'additives_fr',
#  'nutrition_grade_fr',
#  'pnns_groups_1',
#  'energy_100g',
#  'fat_100g',
#  'saturated_fat_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  'fiber_100g',
#  'proteins_100g',
#  'salt_100g',
#  'sodium_100g',
#  'nutrition_score_fr_100g']

# %% [markdown]
# ### Verification des valeurs manquantes apres corrections

# %%
def get_missing_values(df_work, pourcentage, affiche_heatmap):
    """Indicateurs sur les variables manquantes
       @param in : df_work dataframe obligatoire
                   pourcentage : boolean si True affiche le nombre heatmap
                   affiche_heatmap : boolean si True affiche la heatmap
       @param out : none
    """

    # 1. Nombre de valeurs manquantes totales
    nb_nan_tot = df_work.isna().sum().sum()
    nb_donnees_tot = np.prod(df_work.shape)
    pourc_nan_tot = round((nb_nan_tot / nb_donnees_tot) * 100, 2)
    print(
        f'Valeurs manquantes :{nb_nan_tot} NaN pour {nb_donnees_tot} données ({pourc_nan_tot} %)')

    if pourcentage:
        print("-------------------------------------------------------------")
        print("Nombre et pourcentage de valeurs manquantes par variable\n")
        # 2. Visualisation du nombre et du pourcentage de valeurs manquantes
        # par variable
        values = df_work.isnull().sum()
        percentage = 100 * values / len(df_work)
        table = pd.concat([values, percentage.round(2)], axis=1)
        table.columns = [
            'Nombres de valeurs manquantes',
            '% de valeurs manquantes']
        display(table[table['Nombres de valeurs manquantes'] != 0]
                .sort_values('% de valeurs manquantes', ascending=False)
                .style.background_gradient('seismic'))

    if affiche_heatmap:
        print("-------------------------------------------------------------")
        print("Heatmap de visualisation des valeurs manquantes")
        # 3. Heatmap de visualisation des valeurs manquantes
        plt.figure(figsize=(20, 10))
        sns.heatmap(df_work.isna(), cbar=False)
        plt.show()

# %%
get_missing_values(data_fr_completed, True, False)
# Out:
# Valeurs manquantes :42850 NaN pour 183011 données (23.41 %)
# -------------------------------------------------------------
# Nombre et pourcentage de valeurs manquantes par variable
# <style type="text/css">
# #T_18167_row0_col0, #T_18167_row0_col1, #T_18167_row1_col0, #T_18167_row1_col1 {
#   background-color: #800000;
#   color: #f1f1f1;
# }
# #T_18167_row2_col0, #T_18167_row2_col1 {
#   background-color: #ac0000;
#   color: #f1f1f1;
# }
# #T_18167_row3_col0, #T_18167_row3_col1, #T_18167_row4_col0, #T_18167_row4_col1, #T_18167_row5_col0, #T_18167_row5_col1 {
#   background-color: #b60000;
#   color: #f1f1f1;
# }
# #T_18167_row6_col0, #T_18167_row6_col1 {
#   background-color: #da0000;
#   color: #f1f1f1;
# }
# #T_18167_row7_col0, #T_18167_row7_col1 {
#   background-color: #ff8585;
#   color: #f1f1f1;
# }
# #T_18167_row8_col0, #T_18167_row8_col1 {
#   background-color: #ffd1d1;
#   color: #000000;
# }
# #T_18167_row9_col0, #T_18167_row9_col1 {
#   background-color: #ffd5d5;
#   color: #000000;
# }
# #T_18167_row10_col0, #T_18167_row10_col1 {
#   background-color: #adadff;
#   color: #000000;
# }
# #T_18167_row11_col0, #T_18167_row11_col1 {
#   background-color: #00004c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_18167">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18167_level0_col0" class="col_heading level0 col0" >Nombres de valeurs manquantes</th>
#       <th id="T_18167_level0_col1" class="col_heading level0 col1" >% de valeurs manquantes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18167_level0_row0" class="row_heading level0 row0" >additives_tags</th>
#       <td id="T_18167_row0_col0" class="data row0 col0" >5012</td>
#       <td id="T_18167_row0_col1" class="data row0 col1" >62.990000</td>
#     </tr>
#     <tr>
#       <th id="T_18167_level0_row1" class="row_heading level0 row1" >additives_fr</th>
#       <td id="T_18167_row1_col0" class="data row1 col0" >5012</td>
#       <td id="T_18167_row1_col1" class="data row1 col1" >62.990000</td>
#     </tr>
#     <tr>
#       <th id="T_18167_level0_row2" class="row_heading level0 row2" >stores</th>
#       <td id="T_18167_row2_col0" class="data row2 col0" >4570</td>
#       <td id="T_18167_row2_col1" class="data row2 col1" >57.430000</td>
#     </tr>
#     <tr>
#       <th id="T_18167_level0_row3" class="row_heading level0 row3" >labels</th>
#       <td id="T_18167_row3_col0" class="data row3 col0" >4473</td>
#       <td id="T_18167_row3_col1" class="data row3 col1" >56.210000</td>
#     </tr>
#     <tr>
#       <th id="T_18167_level0_row4" class="row_heading level0 row4" >labels_tags</th>
#       <td id="T_18167_row4_col0" class="data row4 col0" >4472</td>
#       <td id="T_18167_row4_col1" class="data row4 col1" >56.200000</td>
#     </tr>
#     <tr>
#       <th id="T_18167_level0_row5" class="row_heading level0 row5" >labels_fr</th>
#       <td id="T_18167_row5_col0" class="data row5 col0" >4472</td>
#       <td id="T_18167_row5_col1" class="data row5 col1" >56.200000</td>
#     </tr>
#     <tr>
#       <th id="T_18167_level0_row6" class="row_heading level0 row6" >purchase_places</th>
#       <td id="T_18167_row6_col0" class="data row6 col0" >4127</td>
#       <td id="T_18167_row6_col1" class="data row6 col1" >51.870000</td>
#     </tr>
#     <tr>
#       <th id="T_18167_level0_row7" class="row_heading level0 row7" >ingredients_text</th>
#       <td id="T_18167_row7_col0" class="data row7 col0" >3103</td>
#       <td id="T_18167_row7_col1" class="data row7 col1" >39.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18167_level0_row8" class="row_heading level0 row8" >fat_100g</th>
#       <td id="T_18167_row8_col0" class="data row8 col0" >2737</td>
#       <td id="T_18167_row8_col1" class="data row8 col1" >34.400000</td>
#     </tr>
#     <tr>
#       <th id="T_18167_level0_row9" class="row_heading level0 row9" >carbohydrates_100g</th>
#       <td id="T_18167_row9_col0" class="data row9 col0" >2729</td>
#       <td id="T_18167_row9_col1" class="data row9 col1" >34.300000</td>
#     </tr>
#     <tr>
#       <th id="T_18167_level0_row10" class="row_heading level0 row10" >fiber_100g</th>
#       <td id="T_18167_row10_col0" class="data row10 col0" >2124</td>
#       <td id="T_18167_row10_col1" class="data row10 col1" >26.690000</td>
#     </tr>
#     <tr>
#       <th id="T_18167_level0_row11" class="row_heading level0 row11" >brands</th>
#       <td id="T_18167_row11_col0" class="data row11 col0" >19</td>
#       <td id="T_18167_row11_col1" class="data row11 col1" >0.240000</td>
#     </tr>
#   </tbody>
# </table>

# %%
data_fr_completed.drop(['additives_fr', 'additives_tags', 'url'], axis=1, inplace=True)

# %%
get_missing_values(data_fr_completed, True, False)
# Out:
# Valeurs manquantes :32826 NaN pour 159140 données (20.63 %)
# -------------------------------------------------------------
# Nombre et pourcentage de valeurs manquantes par variable
# <style type="text/css">
# #T_1e837_row0_col0, #T_1e837_row0_col1 {
#   background-color: #800000;
#   color: #f1f1f1;
# }
# #T_1e837_row1_col0, #T_1e837_row1_col1, #T_1e837_row2_col0, #T_1e837_row2_col1, #T_1e837_row3_col0, #T_1e837_row3_col1 {
#   background-color: #8a0000;
#   color: #f1f1f1;
# }
# #T_1e837_row4_col0, #T_1e837_row4_col1 {
#   background-color: #b00000;
#   color: #f1f1f1;
# }
# #T_1e837_row5_col0, #T_1e837_row5_col1 {
#   background-color: #ff4949;
#   color: #f1f1f1;
# }
# #T_1e837_row6_col0, #T_1e837_row6_col1, #T_1e837_row7_col0, #T_1e837_row7_col1 {
#   background-color: #ff9d9d;
#   color: #000000;
# }
# #T_1e837_row8_col0, #T_1e837_row8_col1 {
#   background-color: #d9d9ff;
#   color: #000000;
# }
# #T_1e837_row9_col0, #T_1e837_row9_col1 {
#   background-color: #00004c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1e837">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e837_level0_col0" class="col_heading level0 col0" >Nombres de valeurs manquantes</th>
#       <th id="T_1e837_level0_col1" class="col_heading level0 col1" >% de valeurs manquantes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e837_level0_row0" class="row_heading level0 row0" >stores</th>
#       <td id="T_1e837_row0_col0" class="data row0 col0" >4570</td>
#       <td id="T_1e837_row0_col1" class="data row0 col1" >57.430000</td>
#     </tr>
#     <tr>
#       <th id="T_1e837_level0_row1" class="row_heading level0 row1" >labels</th>
#       <td id="T_1e837_row1_col0" class="data row1 col0" >4473</td>
#       <td id="T_1e837_row1_col1" class="data row1 col1" >56.210000</td>
#     </tr>
#     <tr>
#       <th id="T_1e837_level0_row2" class="row_heading level0 row2" >labels_tags</th>
#       <td id="T_1e837_row2_col0" class="data row2 col0" >4472</td>
#       <td id="T_1e837_row2_col1" class="data row2 col1" >56.200000</td>
#     </tr>
#     <tr>
#       <th id="T_1e837_level0_row3" class="row_heading level0 row3" >labels_fr</th>
#       <td id="T_1e837_row3_col0" class="data row3 col0" >4472</td>
#       <td id="T_1e837_row3_col1" class="data row3 col1" >56.200000</td>
#     </tr>
#     <tr>
#       <th id="T_1e837_level0_row4" class="row_heading level0 row4" >purchase_places</th>
#       <td id="T_1e837_row4_col0" class="data row4 col0" >4127</td>
#       <td id="T_1e837_row4_col1" class="data row4 col1" >51.870000</td>
#     </tr>
#     <tr>
#       <th id="T_1e837_level0_row5" class="row_heading level0 row5" >ingredients_text</th>
#       <td id="T_1e837_row5_col0" class="data row5 col0" >3103</td>
#       <td id="T_1e837_row5_col1" class="data row5 col1" >39.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1e837_level0_row6" class="row_heading level0 row6" >fat_100g</th>
#       <td id="T_1e837_row6_col0" class="data row6 col0" >2737</td>
#       <td id="T_1e837_row6_col1" class="data row6 col1" >34.400000</td>
#     </tr>
#     <tr>
#       <th id="T_1e837_level0_row7" class="row_heading level0 row7" >carbohydrates_100g</th>
#       <td id="T_1e837_row7_col0" class="data row7 col0" >2729</td>
#       <td id="T_1e837_row7_col1" class="data row7 col1" >34.300000</td>
#     </tr>
#     <tr>
#       <th id="T_1e837_level0_row8" class="row_heading level0 row8" >fiber_100g</th>
#       <td id="T_1e837_row8_col0" class="data row8 col0" >2124</td>
#       <td id="T_1e837_row8_col1" class="data row8 col1" >26.690000</td>
#     </tr>
#     <tr>
#       <th id="T_1e837_level0_row9" class="row_heading level0 row9" >brands</th>
#       <td id="T_1e837_row9_col0" class="data row9 col0" >19</td>
#       <td id="T_1e837_row9_col1" class="data row9 col1" >0.240000</td>
#     </tr>
#   </tbody>
# </table>

# %%
cols = data_fr_completed.select_dtypes(include=[np.number]).columns.to_list()

# %%
corr = data_fr_completed[cols].corr()

# %%
plt.figure(figsize = (10,8))
plt.rcParams.update({'font.size': 12})
sns.heatmap(corr, cmap = 'viridis', vmin = -1, vmax = 1, center = 0, annot=True, fmt=".2f", square=True, linewidths=.5)
plt.show()

# %%
# verifier si certains groupes de produit sont plus impactes par les valeurs manquantes
nan_par_groupe = data_fr_completed.groupby("pnns_groups_1").apply(lambda x: x.isnull().mean() * 100)

# Calculer les statistiques globales sur les valeurs manquantes par groupe
nan_par_groupe_sum = nan_par_groupe.describe()

nan_par_groupe_sum
# Out:
#        product_name     brands     labels  labels_tags  labels_fr  \
# count          10.0  10.000000  10.000000    10.000000  10.000000
# mean            0.0   0.102495  41.583100    41.578162  41.578162
# std             0.0   0.139192  15.690371    15.684351  15.684351
# min             0.0   0.000000  18.421053    18.421053  18.421053
# 25%             0.0   0.000000  32.489355    32.489355  32.489355
# 50%             0.0   0.000000  37.278327    37.278327  37.278327
# 75%             0.0   0.199625  49.205350    49.205350  49.205350
# max             0.0   0.340832  72.733470    72.733470  72.733470
#
#        purchase_places     stores  ingredients_text  nutrition_grade_fr  \
# count        10.000000  10.000000         10.000000                10.0
# mean         28.659591  36.093648         15.982916                 0.0
# std          22.955529  21.095853         23.531981                 0.0
# min           9.178744  16.666667          0.000000                 0.0
# 25%          17.340142  26.225846          5.856782                 0.0
# 50%          20.614908  31.139462          9.307137                 0.0
# 75%          30.506714  34.920323         11.203952                 0.0
# max          86.980232  88.582140         80.708930                 0.0
#
#        pnns_groups_1  energy_100g   fat_100g  saturated_fat_100g  \
# count           10.0         10.0  10.000000                10.0
# mean             0.0          0.0  12.578891                 0.0
# std              0.0          0.0  23.106232                 0.0
# min              0.0          0.0   0.000000                 0.0
# 25%              0.0          0.0   3.150822                 0.0
# 50%              0.0          0.0   4.912601                 0.0
# 75%              0.0          0.0   6.762858                 0.0
# max              0.0          0.0  77.096115                 0.0
#
#        carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# count           10.000000         10.0   10.000000           10.0       10.0
# mean            12.644300          0.0   34.080002            0.0        0.0
# std             23.061861          0.0   16.346189            0.0        0.0
# min              0.000000          0.0    8.145876            0.0        0.0
# 25%              3.557546          0.0   24.220041            0.0        0.0
# 50%              4.866980          0.0   34.611036            0.0        0.0
# 75%              6.792337          0.0   44.193814            0.0        0.0
# max             77.130198          0.0   62.318841            0.0        0.0
#
#        sodium_100g  nutrition_score_fr_100g
# count         10.0                     10.0
# mean           0.0                      0.0
# std            0.0                      0.0
# min            0.0                      0.0
# 25%            0.0                      0.0
# 50%            0.0                      0.0
# 75%            0.0                      0.0
# max            0.0                      0.0

# %% [markdown]
# ## Imputation avec KNNImputer + Analyse Uni/Bivariee

# %% [markdown]
# ### Les colonnes fortement corrélées peuvent servir pour une imputation par régression ou KNN.
# #### Compléter saturated_fat_100g à partir de fat_100g.
# #### Compléter sugars_100g à partir de carbohydrates_100g.

# %%
nan_values = data_fr_completed.isnull().mean() * 100

# Trier les colonnes par pourcentage de valeurs manquantes
missing_values_sorted = nan_values.sort_values(ascending=False)

missing_values_sorted
# Out:
# stores                     57.433706
# labels                     56.214654
# labels_tags                56.202086
# labels_fr                  56.202086
# purchase_places            51.866281
# ingredients_text           38.997109
# fat_100g                   34.397386
# carbohydrates_100g         34.296846
# fiber_100g                 26.693477
# brands                      0.238783
# product_name                0.000000
# sodium_100g                 0.000000
# salt_100g                   0.000000
# proteins_100g               0.000000
# energy_100g                 0.000000
# sugars_100g                 0.000000
# saturated_fat_100g          0.000000
# pnns_groups_1               0.000000
# nutrition_grade_fr          0.000000
# nutrition_score_fr_100g     0.000000
# dtype: float64

# %%
# creation d'une variable copie
data_fr_knn_completed = data_fr_completed.copy()

# Sélection des colonnes fortement corrélées pour une imputation automatique
columns_to_impute = ['saturated_fat_100g', 'fat_100g', 'energy_100g', 'carbohydrates_100g', 'sugars_100g', 'fiber_100g', 'proteins_100g', 'sodium_100g', 'salt_100g', 'nutrition_score_fr_100g']

# %%
# Préparer les données pour KNN Imputation
data_for_imputation = data_fr_knn_completed[columns_to_impute]

# %%
# Initialiser le KNN Imputer
knn_imputer = KNNImputer(n_neighbors=10)

# %%
# Appliquer l'imputation
data_retained_imputed = pd.DataFrame(knn_imputer.fit_transform(data_for_imputation), columns=columns_to_impute, index=data_for_imputation.index)

# %%
# Ajouter les données imputées au dataset original
data_fr_knn_completed[columns_to_impute] = data_retained_imputed

# %%
# Vérifier les valeurs manquantes après imputation
missing_after_imputation = data_fr_knn_completed[columns_to_impute].isnull().sum()

missing_after_imputation
# Out:
# saturated_fat_100g         0
# fat_100g                   0
# energy_100g                0
# carbohydrates_100g         0
# sugars_100g                0
# fiber_100g                 0
# proteins_100g              0
# sodium_100g                0
# salt_100g                  0
# nutrition_score_fr_100g    0
# dtype: int64

# %%
nan_values = data_fr_knn_completed.isnull().mean() * 100

# Trier les colonnes par pourcentage de valeurs manquantes
missing_values_sorted = nan_values.sort_values(ascending=False)

missing_values_sorted
# Out:
# stores                     57.433706
# labels                     56.214654
# labels_tags                56.202086
# labels_fr                  56.202086
# purchase_places            51.866281
# ingredients_text           38.997109
# brands                      0.238783
# product_name                0.000000
# sugars_100g                 0.000000
# sodium_100g                 0.000000
# salt_100g                   0.000000
# proteins_100g               0.000000
# fiber_100g                  0.000000
# energy_100g                 0.000000
# carbohydrates_100g          0.000000
# saturated_fat_100g          0.000000
# fat_100g                    0.000000
# pnns_groups_1               0.000000
# nutrition_grade_fr          0.000000
# nutrition_score_fr_100g     0.000000
# dtype: float64

# %%
data_fr_knn_completed
# Out:
#                              product_name            brands  \
# 226                 Pepsi, Nouveau goût !             Pepsi
# 240                                   7Up       7Up,Pepsico
# 493               Carrot & Coriander soup               NaN
# 523                        Masala Ketchup  Mark And Spencer
# 564          Pur Soup' Velouté de légumes            Liebig
# ...                                   ...               ...
# 320628      Boisson au soja (soy bean 8%)             Yeo's
# 320629               Yeo's Soy Bean Drink             Yeo's
# 320649          Glinter Soft Drink Lychee           Glinter
# 320660                Lait Soja Brique 1L          Marigold
# 320680  Princes Tuna Chunks In Brine 160G           Princes
#
#                                                    labels  \
# 226                                                   NaN
# 240                                                   NaN
# 493                                                   NaN
# 523                                                   NaN
# 564     Sans colorants,Sans conservateurs,Cuisiné en F...
# ...                                                   ...
# 320628                                                NaN
# 320629         Bio,Bio européen,AB Agriculture Biologique
# 320649                                                NaN
# 320660                                                NaN
# 320680                                                NaN
#
#                                               labels_tags  \
# 226                                                   NaN
# 240                                                   NaN
# 493                                                   NaN
# 523                                                   NaN
# 564     en:no-colorings,en:no-preservatives,fr:cuisine...
# ...                                                   ...
# 320628                                                NaN
# 320629  en:organic,en:eu-organic,fr:ab-agriculture-bio...
# 320649                                                NaN
# 320660                                                NaN
# 320680                                                NaN
#
#                                                 labels_fr    purchase_places  \
# 226                                                   NaN              Avion
# 240                                                   NaN  Courrières,France
# 493                                                   NaN                NaN
# 523                                                   NaN                NaN
# 564     Sans colorants,Sans conservateurs,Cuisine-en-f...          Marseille
# ...                                                   ...                ...
# 320628                                                NaN       Paris France
# 320629         Bio,Bio européen,AB Agriculture Biologique                NaN
# 320649                                                NaN                NaN
# 320660                                                NaN                NaN
# 320680                                                NaN                NaN
#
#                 stores                                   ingredients_text  \
# 226                NaN  Eau gazéifiée, sucre, colorant caramel E150d, ...
# 240     Cora Cafétéria  Eau gazéifiée, sucre, acidifiants (acide citri...
# 493                NaN                                                NaN
# 523                NaN                                                NaN
# 564          U Express  eau, légumes 38% (jus de tomates à base de con...
# ...                ...                                                ...
# 320628     Tang Frères  Eau, extrait de _soja_ (_soja_ 8 %), sucre de ...
# 320629             NaN                                                NaN
# 320649             NaN                                                NaN
# 320660             NaN                                                NaN
# 320680             NaN                                                NaN
#
#        nutrition_grade_fr      pnns_groups_1  energy_100g  fat_100g  \
# 226                     E           boissons    42.304015     0.000
# 240                     E           boissons    42.304015     0.000
# 493                     B       a renseigner    30.114723     1.400
# 523                     C       a renseigner    96.080306     0.870
# 564                     B  fruits et legumes    44.933078     2.100
# ...                   ...                ...          ...       ...
# 320628                  B           boissons    51.147228     1.100
# 320629                  E           boissons    53.059273     0.082
# 320649                  D       a renseigner    80.066922     3.172
# 320660                  B       a renseigner    55.927342     1.360
# 320680                  B       a renseigner    98.948375     0.590
#
#         saturated_fat_100g  carbohydrates_100g  sugars_100g  fiber_100g  \
# 226                    0.0               10.40         10.4         0.0
# 240                    0.0               10.40         10.4         0.0
# 493                    0.8                3.60          2.7         1.0
# 523                    0.1               19.67         18.0         3.0
# 564                    0.7                5.30          2.4         0.8
# ...                    ...                 ...          ...         ...
# 320628                 0.2                8.10          7.8         0.0
# 320629                 0.2               12.05          8.3         0.0
# 320649                 0.0                9.50         20.0         0.0
# 320660                 2.0                9.50          8.0         0.0
# 320680                 0.1                0.56          0.0         0.1
#
#         proteins_100g  salt_100g  sodium_100g  nutrition_score_fr_100g
# 226               0.0     0.0254     0.010000                     13.0
# 240               0.0     0.1000     0.039370                     13.0
# 493               0.3     0.6300     0.248031                      1.0
# 523               1.7     1.2300     0.484252                      4.0
# 564               0.8     0.7500     0.295276                      2.0
# ...               ...        ...          ...                      ...
# 320628            2.0     0.0000     0.000000                      0.0
# 320629            2.0     0.0100     0.003937                     14.0
# 320649            0.0    28.0000    11.023622                     14.0
# 320660            2.0     0.0000     0.000000                      1.0
# 320680           23.5     1.0500     0.413386                      0.0
#
# [7957 rows x 20 columns]

# %%
get_missing_values(data_fr_knn_completed, True, False)
# Out:
# Valeurs manquantes :25236 NaN pour 159140 données (15.86 %)
# -------------------------------------------------------------
# Nombre et pourcentage de valeurs manquantes par variable
# <style type="text/css">
# #T_6eeb5_row0_col0, #T_6eeb5_row0_col1 {
#   background-color: #800000;
#   color: #f1f1f1;
# }
# #T_6eeb5_row1_col0, #T_6eeb5_row1_col1, #T_6eeb5_row2_col0, #T_6eeb5_row2_col1, #T_6eeb5_row3_col0, #T_6eeb5_row3_col1 {
#   background-color: #8a0000;
#   color: #f1f1f1;
# }
# #T_6eeb5_row4_col0, #T_6eeb5_row4_col1 {
#   background-color: #b00000;
#   color: #f1f1f1;
# }
# #T_6eeb5_row5_col0, #T_6eeb5_row5_col1 {
#   background-color: #ff4949;
#   color: #f1f1f1;
# }
# #T_6eeb5_row6_col0, #T_6eeb5_row6_col1 {
#   background-color: #00004c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6eeb5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6eeb5_level0_col0" class="col_heading level0 col0" >Nombres de valeurs manquantes</th>
#       <th id="T_6eeb5_level0_col1" class="col_heading level0 col1" >% de valeurs manquantes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6eeb5_level0_row0" class="row_heading level0 row0" >stores</th>
#       <td id="T_6eeb5_row0_col0" class="data row0 col0" >4570</td>
#       <td id="T_6eeb5_row0_col1" class="data row0 col1" >57.430000</td>
#     </tr>
#     <tr>
#       <th id="T_6eeb5_level0_row1" class="row_heading level0 row1" >labels</th>
#       <td id="T_6eeb5_row1_col0" class="data row1 col0" >4473</td>
#       <td id="T_6eeb5_row1_col1" class="data row1 col1" >56.210000</td>
#     </tr>
#     <tr>
#       <th id="T_6eeb5_level0_row2" class="row_heading level0 row2" >labels_tags</th>
#       <td id="T_6eeb5_row2_col0" class="data row2 col0" >4472</td>
#       <td id="T_6eeb5_row2_col1" class="data row2 col1" >56.200000</td>
#     </tr>
#     <tr>
#       <th id="T_6eeb5_level0_row3" class="row_heading level0 row3" >labels_fr</th>
#       <td id="T_6eeb5_row3_col0" class="data row3 col0" >4472</td>
#       <td id="T_6eeb5_row3_col1" class="data row3 col1" >56.200000</td>
#     </tr>
#     <tr>
#       <th id="T_6eeb5_level0_row4" class="row_heading level0 row4" >purchase_places</th>
#       <td id="T_6eeb5_row4_col0" class="data row4 col0" >4127</td>
#       <td id="T_6eeb5_row4_col1" class="data row4 col1" >51.870000</td>
#     </tr>
#     <tr>
#       <th id="T_6eeb5_level0_row5" class="row_heading level0 row5" >ingredients_text</th>
#       <td id="T_6eeb5_row5_col0" class="data row5 col0" >3103</td>
#       <td id="T_6eeb5_row5_col1" class="data row5 col1" >39.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6eeb5_level0_row6" class="row_heading level0 row6" >brands</th>
#       <td id="T_6eeb5_row6_col0" class="data row6 col0" >19</td>
#       <td id="T_6eeb5_row6_col1" class="data row6 col1" >0.240000</td>
#     </tr>
#   </tbody>
# </table>

# %%
data_fr_knn_completed.drop(['labels', 'labels_tags', 'labels_fr'], axis=1, inplace=True)

# %%
data_fr_knn_completed
# Out:
#                              product_name            brands  \
# 226                 Pepsi, Nouveau goût !             Pepsi
# 240                                   7Up       7Up,Pepsico
# 493               Carrot & Coriander soup               NaN
# 523                        Masala Ketchup  Mark And Spencer
# 564          Pur Soup' Velouté de légumes            Liebig
# ...                                   ...               ...
# 320628      Boisson au soja (soy bean 8%)             Yeo's
# 320629               Yeo's Soy Bean Drink             Yeo's
# 320649          Glinter Soft Drink Lychee           Glinter
# 320660                Lait Soja Brique 1L          Marigold
# 320680  Princes Tuna Chunks In Brine 160G           Princes
#
#           purchase_places          stores  \
# 226                 Avion             NaN
# 240     Courrières,France  Cora Cafétéria
# 493                   NaN             NaN
# 523                   NaN             NaN
# 564             Marseille       U Express
# ...                   ...             ...
# 320628       Paris France     Tang Frères
# 320629                NaN             NaN
# 320649                NaN             NaN
# 320660                NaN             NaN
# 320680                NaN             NaN
#
#                                          ingredients_text nutrition_grade_fr  \
# 226     Eau gazéifiée, sucre, colorant caramel E150d, ...                  E
# 240     Eau gazéifiée, sucre, acidifiants (acide citri...                  E
# 493                                                   NaN                  B
# 523                                                   NaN                  C
# 564     eau, légumes 38% (jus de tomates à base de con...                  B
# ...                                                   ...                ...
# 320628  Eau, extrait de _soja_ (_soja_ 8 %), sucre de ...                  B
# 320629                                                NaN                  E
# 320649                                                NaN                  D
# 320660                                                NaN                  B
# 320680                                                NaN                  B
#
#             pnns_groups_1  energy_100g  fat_100g  saturated_fat_100g  \
# 226              boissons    42.304015     0.000                 0.0
# 240              boissons    42.304015     0.000                 0.0
# 493          a renseigner    30.114723     1.400                 0.8
# 523          a renseigner    96.080306     0.870                 0.1
# 564     fruits et legumes    44.933078     2.100                 0.7
# ...                   ...          ...       ...                 ...
# 320628           boissons    51.147228     1.100                 0.2
# 320629           boissons    53.059273     0.082                 0.2
# 320649       a renseigner    80.066922     3.172                 0.0
# 320660       a renseigner    55.927342     1.360                 2.0
# 320680       a renseigner    98.948375     0.590                 0.1
#
#         carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# 226                  10.40         10.4         0.0            0.0     0.0254
# 240                  10.40         10.4         0.0            0.0     0.1000
# 493                   3.60          2.7         1.0            0.3     0.6300
# 523                  19.67         18.0         3.0            1.7     1.2300
# 564                   5.30          2.4         0.8            0.8     0.7500
# ...                    ...          ...         ...            ...        ...
# 320628                8.10          7.8         0.0            2.0     0.0000
# 320629               12.05          8.3         0.0            2.0     0.0100
# 320649                9.50         20.0         0.0            0.0    28.0000
# 320660                9.50          8.0         0.0            2.0     0.0000
# 320680                0.56          0.0         0.1           23.5     1.0500
#
#         sodium_100g  nutrition_score_fr_100g
# 226        0.010000                     13.0
# 240        0.039370                     13.0
# 493        0.248031                      1.0
# 523        0.484252                      4.0
# 564        0.295276                      2.0
# ...             ...                      ...
# 320628     0.000000                      0.0
# 320629     0.003937                     14.0
# 320649    11.023622                     14.0
# 320660     0.000000                      1.0
# 320680     0.413386                      0.0
#
# [7957 rows x 17 columns]
